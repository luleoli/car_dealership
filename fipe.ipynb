# %%
import time
import random
import requests
import json
import pandas as pd

# %%
mdls_consult =   {'VW - VolksWagen' : ['gol', 'polo', 'voyage', 'fox', 'saveiro'],
                  'GM - Chevrolet' : ['onix', 'prisma'],
                  'Hyundai' : ['hb20', 'creta'],
                  'Fiat' : ['palio', 'argo', 'mobi', 'logan', 'fastback', 'pulse'],
                  'Ford' : ['ka', 'ecosport', 'focus'],
                  'Renault' : ['sandero', 'logan', 'kwid'],
                  'Toyota' : ['corolla', 'etios'],
                  'Honda' : ['civic', 'city'],
                  'Nissan' : ['versa', 'kicks'],
                  'Jeep' : ['renegade', 'compass'],
                  'Peugeot' : ['208']}

# %%
_LAST_CALL = 0.0

BASE = "https://veiculos.fipe.org.br/api/veiculos"

S = requests.Session()
S.headers.update({
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json, text/plain, */*",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://veiculos.fipe.org.br",
    "Referer": "https://veiculos.fipe.org.br/",
    "X-Requested-With": "XMLHttpRequest",
})


S.get("https://veiculos.fipe.org.br/")

def post(path: str, data: dict, *, min_delay=1.0, max_delay=5.0) -> dict:
    global _LAST_CALL

    # throttle BEFORE the request
    now = time.time()
    elapsed = now - _LAST_CALL
    target = random.uniform(min_delay, max_delay)
    if elapsed < target:
        time.sleep(target - elapsed)

    r = S.post(f"{BASE}/{path}", data=data, timeout=30)
    _LAST_CALL = time.time()  # mark after request is made

    r.raise_for_status()
    return r.json()

cod_ref = 333
tipo = 1
regra_ano_recente = 2019

# %%
# Commonly-used “flow” endpoints (names can change over time):
# - ConsultarTabelaDeReferencia
# - ConsultarMarcas
# - ConsultarModelos
# - ConsultarAnoModelo
# - ConsultarValor

# 1) Reference tables
refs = post("ConsultarTabelaDeReferencia", {})
with open("refs.json", "w", encoding="utf-8") as f:
    json.dump(refs, f, ensure_ascii=False, indent=2)

# %%
marcas = post("ConsultarMarcas", {
    "codigoTipoVeiculo": tipo,
    "codigoTabelaReferencia": cod_ref
})

marcas_dict = {m['Label']:m['Value'] for m in marcas}
with open("marcas.json", "w", encoding="utf-8") as f:
    json.dump(marcas_dict, f, ensure_ascii=False, indent=2)

# %%
with open("marcas.json", "r", encoding="utf-8") as f:
    marcas_dict = json.load(f)

# %%
# Loop through each brand and its target model keywords
for marca_, mdls in mdls_consult.items():
    print(f"[brand] {marca_}")

    # Get brand code from lookup dictionary
    cod_marca = marcas_dict.get(marca_)

    # Fetch all models for this brand
    modelos_resp = post("ConsultarModelos", {
            "codigoTipoVeiculo": tipo,
            "codigoTabelaReferencia": cod_ref,
            "codigoMarca": cod_marca
        })
    
    # Normalize API response and build model code lookup
    modelos = modelos_resp.get("Modelos", modelos_resp)
    modelos_dict = {m['Label']: m['Value'] for m in modelos}

    # Persist all models for the brand
    with open(f"{marca_}.json", "a", encoding="utf-8") as f:
        f.write(json.dumps(modelos_dict, ensure_ascii=False, indent=2) + "\n")

    for mdl_lbl in mdls:
        print(f"  [model_lbl] {mdl_lbl}")
        # Filter models that match the target keyword
        modelos_target = [m for m in modelos if mdl_lbl in m.get("Label", "").lower()]
        modelos_target_dict = {m['Label']: m['Value'] for m in modelos_target}
            
        # For each target model keyword
        for mdl in modelos_target_dict.keys():
            print(f"  [model] {mdl}")
            
            # Fetch available years for the selected model code
            anos = post("ConsultarAnoModelo", {
                "codigoTipoVeiculo": tipo,
                "codigoTabelaReferencia": cod_ref,
                "codigoMarca": cod_marca,
                "codigoModelo": modelos_target_dict.get(mdl)
            })

            # Build year code lookup
            anos_dict = {a['Label']: a['Value'] for a in anos}


            # Keep only years >= regra_ano_recente
            anos_recentes = {
                k: v
                for k, v in anos_dict.items()
                if int(k[:4]) >= regra_ano_recente and int(k[:4]) <= 2026
            }

            # Store model code and its years
            modelos_target_dict[mdl] = {
                "codigo_modelo": modelos_target_dict.get(mdl),
                "anos": anos_recentes
            }

            # Fetch detailed values for each recent year
            for ano_val, ano_code in anos_recentes.items():
                print(f"    [year] {ano_val}")
                det = post("ConsultarValorComTodosParametros", {
                    "codigoTipoVeiculo": tipo,
                    "codigoTabelaReferencia": cod_ref,
                    "codigoMarca": cod_marca,
                    "codigoModelo": modelos_target_dict.get(mdl)["codigo_modelo"],
                    "anoModelo": ano_code.split("-")[0],
                    "codigoTipoCombustivel": ano_code.split("-")[1],
                    "tipoConsulta": "tradicional"
                })

                # Attach details to the year entry
                modelos_target_dict[mdl]['anos'][ano_val] = {
                    "codigo_ano": modelos_target_dict[mdl]['anos'].get(ano_val),
                    "detalhes": det
                }

                print(f"[modelo] {mdl}, [ano] {ano_val.split('-')[0]}, [valor] {det.get('Valor')}")

                # Persist target model details
                with open(f"{marca_}_target.json", "a", encoding="utf-8") as f:
                    f.write(json.dumps(modelos_target_dict, ensure_ascii=False, indent=2) + "\n")
# Out:
# [brand] Peugeot
#   [model_lbl] 208
#   [model] 208 Active 1.0 Flex 5p Mec.
#     [year] 2026 Flex
# [modelo] 208 Active 1.0 Flex 5p Mec., [ano] 2026 Flex, [valor] R$ 81.442,00
#     [year] 2025 Flex
# [modelo] 208 Active 1.0 Flex 5p Mec., [ano] 2025 Flex, [valor] R$ 76.837,00
#   [model] 208 Active 1.0 Turbo 200 5p Aut.
#     [year] 2026 Flex
# [modelo] 208 Active 1.0 Turbo 200 5p Aut., [ano] 2026 Flex, [valor] R$ 95.740,00
#   [model] 208 Active 1.2 Flex 12V 5p Mec.
#     [year] 2020 Flex
# [modelo] 208 Active 1.2 Flex 12V 5p Mec., [ano] 2020 Flex, [valor] R$ 46.202,00
#     [year] 2019 Flex
# [modelo] 208 Active 1.2 Flex 12V 5p Mec., [ano] 2019 Flex, [valor] R$ 43.673,00
#   [model] 208 Active 1.6 Flex 16V 5p Aut.
#     [year] 2024 Flex
# [modelo] 208 Active 1.6 Flex 16V 5p Aut., [ano] 2024 Flex, [valor] R$ 82.058,00
#     [year] 2023 Flex
# [modelo] 208 Active 1.6 Flex 16V 5p Aut., [ano] 2023 Flex, [valor] R$ 71.256,00
#     [year] 2022 Flex
# [modelo] 208 Active 1.6 Flex 16V 5p Aut., [ano] 2022 Flex, [valor] R$ 66.808,00
#     [year] 2021 Flex
# [modelo] 208 Active 1.6 Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 65.178,00
#   [model] 208 Active Pack 1.2 Flex 12V 5p Mec.
#     [year] 2019 Flex
# [modelo] 208 Active Pack 1.2 Flex 12V 5p Mec., [ano] 2019 Flex, [valor] R$ 48.733,00
#   [model] 208 Active Pack 1.6 Flex 16V 5p Aut.
#     [year] 2021 Flex
# [modelo] 208 Active Pack 1.6 Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 66.058,00
#     [year] 2020 Flex
# [modelo] 208 Active Pack 1.6 Flex 16V 5p Aut., [ano] 2020 Flex, [valor] R$ 60.344,00
#     [year] 2019 Flex
# [modelo] 208 Active Pack 1.6 Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 55.869,00
#   [model] 208 Active/Active Pack 1.5 Flex 8V 5p
#   [model] 208 Allure 1.0 Turbo 200 5p Aut.
#     [year] 2026 Flex
# [modelo] 208 Allure 1.0 Turbo 200 5p Aut., [ano] 2026 Flex, [valor] R$ 109.322,00
#   [model] 208 Allure 1.0 Turbo Flex 5p Aut.
#     [year] 2025 Flex
# [modelo] 208 Allure 1.0 Turbo Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 97.579,00
#     [year] 2024 Flex
# [modelo] 208 Allure 1.0 Turbo Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 86.207,00
#   [model] 208 Allure 1.2 Flex 12V 5p Mec.
#     [year] 2020 Flex
# [modelo] 208 Allure 1.2 Flex 12V 5p Mec., [ano] 2020 Flex, [valor] R$ 55.504,00
#     [year] 2019 Flex
# [modelo] 208 Allure 1.2 Flex 12V 5p Mec., [ano] 2019 Flex, [valor] R$ 53.525,00
#   [model] 208 Allure 1.5 Flex 8V 5p
#   [model] 208 Allure 1.6 Flex 16V 5p Aut.
#     [year] 2023 Flex
# [modelo] 208 Allure 1.6 Flex 16V 5p Aut., [ano] 2023 Flex, [valor] R$ 74.938,00
#     [year] 2022 Flex
# [modelo] 208 Allure 1.6 Flex 16V 5p Aut., [ano] 2022 Flex, [valor] R$ 68.870,00
#     [year] 2021 Flex
# [modelo] 208 Allure 1.6 Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 67.190,00
#   [model] 208 Allure inconcert 1.5 Flex 8V 5p Mec.
#   [model] 208 Allure inconcert 1.6 Flex 16V 5p Aut
#   [model] 208 Griffe 1.0 Turbo Flex 5p Aut.
#     [year] 2024 Flex
# [modelo] 208 Griffe 1.0 Turbo Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 95.963,00
#   [model] 208 Griffe 1.6 Flex 16V 5p Aut.
#     [year] 2024 Flex
# [modelo] 208 Griffe 1.6 Flex 16V 5p Aut., [ano] 2024 Flex, [valor] R$ 96.941,00
#     [year] 2023 Flex
# [modelo] 208 Griffe 1.6 Flex 16V 5p Aut., [ano] 2023 Flex, [valor] R$ 86.010,00
#     [year] 2022 Flex
# [modelo] 208 Griffe 1.6 Flex 16V 5p Aut., [ano] 2022 Flex, [valor] R$ 79.431,00
#     [year] 2021 Flex
# [modelo] 208 Griffe 1.6 Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 77.493,00
#     [year] 2020 Flex
# [modelo] 208 Griffe 1.6 Flex 16V 5p Aut., [ano] 2020 Flex, [valor] R$ 65.805,00
#     [year] 2019 Flex
# [modelo] 208 Griffe 1.6 Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 61.513,00
#   [model] 208 Griffe 1.6 Flex 16V 5p Mec.
#   [model] 208 Griffe Bus. 1.6 Flex 5p Aut.
#     [year] 2020 Flex
# [modelo] 208 Griffe Bus. 1.6 Flex 5p Aut., [ano] 2020 Flex, [valor] R$ 66.118,00
#     [year] 2019 Flex
# [modelo] 208 Griffe Bus. 1.6 Flex 5p Aut., [ano] 2019 Flex, [valor] R$ 54.163,00
#   [model] 208 GT 1.0 Turbo 200 5p Aut.
#     [year] 2026 Híbrido
# [modelo] 208 GT 1.0 Turbo 200 5p Aut., [ano] 2026 Híbrido, [valor] R$ 119.804,00
#   [model] 208 GT 1.0 Turbo Flex 5p Aut.
#     [year] 2025 Flex
# [modelo] 208 GT 1.0 Turbo Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 109.842,00
#   [model] 208 GT 1.6 THP Flex 16V 5p Mec.
#     [year] 2020 Flex
# [modelo] 208 GT 1.6 THP Flex 16V 5p Mec., [ano] 2020 Flex, [valor] R$ 77.886,00
#     [year] 2019 Flex
# [modelo] 208 GT 1.6 THP Flex 16V 5p Mec., [ano] 2019 Flex, [valor] R$ 71.521,00
#   [model] 208 Inconcert 1.6 Flex 16V 5p Aut.
#     [year] 2019 Flex
# [modelo] 208 Inconcert 1.6 Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 54.678,00
#   [model] 208 Like 1.0 Flex 6V 5p Mec.
#     [year] 2024 Flex
# [modelo] 208 Like 1.0 Flex 6V 5p Mec., [ano] 2024 Flex, [valor] R$ 67.516,00
#     [year] 2023 Flex
# [modelo] 208 Like 1.0 Flex 6V 5p Mec., [ano] 2023 Flex, [valor] R$ 57.709,00
#   [model] 208 Like 1.6 Flex 16V 5p Mec.
#     [year] 2022 Flex
# [modelo] 208 Like 1.6 Flex 16V 5p Mec., [ano] 2022 Flex, [valor] R$ 54.999,00
#     [year] 2021 Flex
# [modelo] 208 Like 1.6 Flex 16V 5p Mec., [ano] 2021 Flex, [valor] R$ 52.494,00
#     [year] 2020 Flex
# [modelo] 208 Like 1.6 Flex 16V 5p Mec., [ano] 2020 Flex, [valor] R$ 51.181,00
#   [model] 208 Like Essencial 1.6 Flex 16V 5p Mec.
#     [year] 2022 Flex
# [modelo] 208 Like Essencial 1.6 Flex 16V 5p Mec., [ano] 2022 Flex, [valor] R$ 54.929,00
#     [year] 2021 Flex
# [modelo] 208 Like Essencial 1.6 Flex 16V 5p Mec., [ano] 2021 Flex, [valor] R$ 52.287,00
#     [year] 2020 Flex
# [modelo] 208 Like Essencial 1.6 Flex 16V 5p Mec., [ano] 2020 Flex, [valor] R$ 51.008,00
#   [model] 208 Premier 1.6 Flex 16V 5p
#   [model] 208 Roadtrip 1.6 Flex 16V 5p Aut.
#     [year] 2024 Flex
# [modelo] 208 Roadtrip 1.6 Flex 16V 5p Aut., [ano] 2024 Flex, [valor] R$ 83.779,00
#     [year] 2023 Flex
# [modelo] 208 Roadtrip 1.6 Flex 16V 5p Aut., [ano] 2023 Flex, [valor] R$ 80.604,00
#   [model] 208 Sport 1.6 Flex 16V 5p Mec.
#   [model] 208 Style 1.0 Flex 6V 5p Mec.
#     [year] 2026 Flex
# [modelo] 208 Style 1.0 Flex 6V 5p Mec., [ano] 2026 Flex, [valor] R$ 86.320,00
#     [year] 2025 Flex
# [modelo] 208 Style 1.0 Flex 6V 5p Mec., [ano] 2025 Flex, [valor] R$ 82.117,00
#     [year] 2024 Flex
# [modelo] 208 Style 1.0 Flex 6V 5p Mec., [ano] 2024 Flex, [valor] R$ 75.968,00
#     [year] 2023 Flex
# [modelo] 208 Style 1.0 Flex 6V 5p Mec., [ano] 2023 Flex, [valor] R$ 71.231,00
#   [model] 208 Style 1.0 Turbo Flex 5p Aut.
#     [year] 2024 Flex
# [modelo] 208 Style 1.0 Turbo Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 90.524,00
#   [model] 208 URBANTECH1.6 Flex 16V 5p Aut.
#   [model] e-208 GT 5p Aut. (Elétrico)
#     [year] 2023 Elétrico
# [modelo] e-208 GT 5p Aut. (Elétrico), [ano] 2023 Elétrico, [valor] R$ 94.252,00
#     [year] 2022 Elétrico
# [modelo] e-208 GT 5p Aut. (Elétrico), [ano] 2022 Elétrico, [valor] R$ 91.801,00

# %%
def flatten_modelos_keep_all(data):
    rows = []

    for modelo_nome, modelo_data in data.items():

        # Case 1 — model is just a code (no years yet)
        if not isinstance(modelo_data, dict):
            rows.append({
                "Modelo": modelo_nome,
                "CodigoModelo": modelo_data,
                "AnoLabel": None,
                "AnoModelo": None,
                "Combustivel": None,
                "Valor": None,
                "CodigoFipe": None,
                "MesReferencia": None,
                "DataConsulta": None,
            })
            continue

        codigo_modelo = modelo_data.get("codigo_modelo")
        anos = modelo_data.get("anos")

        # Case 2 — model has no years
        if not anos:
            rows.append({
                "Modelo": modelo_nome,
                "CodigoModelo": codigo_modelo,
                "AnoLabel": None,
                "AnoModelo": None,
                "Combustivel": None,
                "Valor": None,
                "CodigoFipe": None,
                "MesReferencia": None,
                "DataConsulta": None,
            })
            continue

        # Case 3 — model has years
        for ano_label, ano_data in anos.items():

            # If year is just a string like "2024-6"
            if not isinstance(ano_data, dict):
                rows.append({
                    "Modelo": modelo_nome,
                    "CodigoModelo": codigo_modelo,
                    "AnoLabel": ano_label,
                    "AnoModelo": int(ano_label[:4]) if ano_label[:4].isdigit() else None,
                    "Combustivel": None,
                    "Valor": None,
                    "CodigoFipe": None,
                    "MesReferencia": None,
                    "DataConsulta": None,
                })
                continue

            detalhes = ano_data.get("detalhes", {})

            rows.append({
                "Modelo": modelo_nome,
                "CodigoModelo": codigo_modelo,
                "AnoLabel": ano_label,
                "AnoModelo": detalhes.get("AnoModelo"),
                "Combustivel": detalhes.get("Combustivel"),
                "Valor": detalhes.get("Valor"),
                "CodigoFipe": detalhes.get("CodigoFipe"),
                "MesReferencia": detalhes.get("MesReferencia"),
                "DataConsulta": detalhes.get("DataConsulta"),
            })

            df = pd.DataFrame(rows)

            df["Valor_num"] = (
            df["Valor"]
            .str.replace("R$ ", "", regex=False)
            .str.replace(".", "", regex=False)
                .str.replace(",", ".", regex=False)
            )

            df["Valor_num"] = pd.to_numeric(df["Valor_num"], errors="coerce")

    return df

# %%
df_all_marcas = pd.DataFrame()

for marca_ in mdls_consult.keys():

    data = {}

    with open(f"{marca_}_target.json", "r", encoding="utf-8") as f:
        buffer = ""
        for line in f:
            buffer += line.strip()
            try:
                obj = json.loads(buffer)
                data.update(obj)
                buffer = ""
            except json.JSONDecodeError:
                continue

    df = flatten_modelos_keep_all(data)
    df["Marca"] = marca_
    df_all_marcas = pd.concat([df_all_marcas, df], ignore_index=True)
    print(f"[{marca_}] rows: {len(df)}, total: {len(df_all_marcas)}")
# Out:
# [VW - VolksWagen] rows: 416, total: 416
# [GM - Chevrolet] rows: 135, total: 551
# [Hyundai] rows: 251, total: 802
# [Fiat] rows: 264, total: 1066
# [Ford] rows: 137, total: 1203
# [Renault] rows: 165, total: 1368
# [Toyota] rows: 134, total: 1502
# [Honda] rows: 110, total: 1612
# [Nissan] rows: 92, total: 1704
# [Jeep] rows: 125, total: 1829
# [Peugeot] rows: 60, total: 1889

# %%
df_all_marcas.to_csv(f"fipe_data_{cod_ref}.csv", index=False, encoding="utf-8-sig")
