# %%
import time
import random
import requests
import json
import pandas as pd

# %%
mdls_consult =   {'VW - VolksWagen' : ['gol', 'polo', 'voyage', 'fox', 'saveiro'],
                'GM - Chevrolet' : ['onix', 'prisma'],
                'Hyundai' : ['hb20', 'creta'],
                'Fiat' : ['palio', 'argo', 'mobi', 'logan'],
                'Ford' : ['ka', 'ecosport', 'focus'],
                'Renault' : ['sandero', 'logan', 'kwid'],
                'Toyota' : ['corolla', 'etios'],
                'Honda' : ['civic', 'city']}

# %%
_LAST_CALL = 0.0

BASE = "https://veiculos.fipe.org.br/api/veiculos"

S = requests.Session()
S.headers.update({
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json, text/plain, */*",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://veiculos.fipe.org.br",
    "Referer": "https://veiculos.fipe.org.br/",
    "X-Requested-With": "XMLHttpRequest",
})


S.get("https://veiculos.fipe.org.br/")

def post(path: str, data: dict, *, min_delay=1.0, max_delay=20.0) -> dict:
    global _LAST_CALL

    # throttle BEFORE the request
    now = time.time()
    elapsed = now - _LAST_CALL
    target = random.uniform(min_delay, max_delay)
    if elapsed < target:
        time.sleep(target - elapsed)

    r = S.post(f"{BASE}/{path}", data=data, timeout=30)
    _LAST_CALL = time.time()  # mark after request is made

    r.raise_for_status()
    return r.json()

cod_ref = 330
tipo = 1
regra_ano_recente = 2018

# %%
# Commonly-used “flow” endpoints (names can change over time):
# - ConsultarTabelaDeReferencia
# - ConsultarMarcas
# - ConsultarModelos
# - ConsultarAnoModelo
# - ConsultarValor

# 1) Reference tables
refs = post("ConsultarTabelaDeReferencia", {})
with open("refs.json", "w", encoding="utf-8") as f:
    json.dump(refs, f, ensure_ascii=False, indent=2)

# %%
marcas = post("ConsultarMarcas", {
    "codigoTipoVeiculo": tipo,
    "codigoTabelaReferencia": cod_ref
})

marcas_dict = {m['Label']:m['Value'] for m in marcas}
with open("marcas.json", "w", encoding="utf-8") as f:
    json.dump(marcas_dict, f, ensure_ascii=False, indent=2)

# %%
with open("marcas.json", "r", encoding="utf-8") as f:
    marcas_dict = json.load(f)

# %%
# Loop through each brand and its target model keywords
for marca_, mdls in mdls_consult.items():
    print(f"[brand] {marca_}")

    # Get brand code from lookup dictionary
    cod_marca = marcas_dict.get(marca_)

    # Fetch all models for this brand
    modelos_resp = post("ConsultarModelos", {
            "codigoTipoVeiculo": tipo,
            "codigoTabelaReferencia": cod_ref,
            "codigoMarca": cod_marca
        })
    
    # Normalize API response and build model code lookup
    modelos = modelos_resp.get("Modelos", modelos_resp)
    modelos_dict = {m['Label']: m['Value'] for m in modelos}

    # Persist all models for the brand
    with open(f"{marca_}.json", "a", encoding="utf-8") as f:
        f.write(json.dumps(modelos_dict, ensure_ascii=False, indent=2) + "\n")

    for mdl_lbl in mdls:
        print(f"  [model_lbl] {mdl_lbl}")
        # Filter models that match the target keyword
        modelos_target = [m for m in modelos if mdl_lbl in m.get("Label", "").lower()]
        modelos_target_dict = {m['Label']: m['Value'] for m in modelos_target}
            
        # For each target model keyword
        for mdl in modelos_target_dict.keys():
            print(f"  [model] {mdl}")
            
            # Fetch available years for the selected model code
            anos = post("ConsultarAnoModelo", {
                "codigoTipoVeiculo": tipo,
                "codigoTabelaReferencia": cod_ref,
                "codigoMarca": cod_marca,
                "codigoModelo": modelos_target_dict.get(mdl)
            })

            # Build year code lookup
            anos_dict = {a['Label']: a['Value'] for a in anos}


            # Keep only years >= regra_ano_recente
            anos_recentes = {
                k: v
                for k, v in anos_dict.items()
                if int(k[:4]) >= regra_ano_recente and int(k[:4]) <= 2026
            }

            # Store model code and its years
            modelos_target_dict[mdl] = {
                "codigo_modelo": modelos_target_dict.get(mdl),
                "anos": anos_recentes
            }

            # Fetch detailed values for each recent year
            for ano_val, ano_code in anos_recentes.items():
                print(f"    [year] {ano_val}")
                det = post("ConsultarValorComTodosParametros", {
                    "codigoTipoVeiculo": tipo,
                    "codigoTabelaReferencia": cod_ref,
                    "codigoMarca": cod_marca,
                    "codigoModelo": modelos_target_dict.get(mdl)["codigo_modelo"],
                    "anoModelo": ano_code.split("-")[0],
                    "codigoTipoCombustivel": ano_code.split("-")[1],
                    "tipoConsulta": "tradicional"
                })

                # Attach details to the year entry
                modelos_target_dict[mdl]['anos'][ano_val] = {
                    "codigo_ano": modelos_target_dict[mdl]['anos'].get(ano_val),
                    "detalhes": det
                }

                print(f"[modelo] {mdl}, [ano] {ano_val.split('-')[0]}, [valor] {det.get('Valor')}")

                # Persist target model details
                with open(f"{marca_}_target.json", "a", encoding="utf-8") as f:
                    f.write(json.dumps(modelos_target_dict, ensure_ascii=False, indent=2) + "\n")
# Out:
# [brand] VW - VolksWagen
#   [model_lbl] gol
#   [model] Gol (novo) 1.0 Mi Total Flex 8V 2p
#   [model] Gol (novo) 1.0 Mi Total Flex 8V 4p
#   [model] Gol (novo) 1.6 Mi Total Flex 8V 2p
#   [model] Gol (novo) 1.6 Mi Total Flex 8V 4p
#   [model] Gol (novo) 1.6 Power/Highi T.Flex 8v 4P
#   [model] Gol 1.0 Flex 12V 5p
#     [year] 2023 Flex
# [modelo] Gol 1.0 Flex 12V 5p, [ano] 2023 Flex, [valor] R$ 55.012,00
#     [year] 2022 Flex
# [modelo] Gol 1.0 Flex 12V 5p, [ano] 2022 Flex, [valor] R$ 50.561,00
#     [year] 2021 Flex
# [modelo] Gol 1.0 Flex 12V 5p, [ano] 2021 Flex, [valor] R$ 45.742,00
#     [year] 2020 Flex
# [modelo] Gol 1.0 Flex 12V 5p, [ano] 2020 Flex, [valor] R$ 43.946,00
#     [year] 2019 Flex
# [modelo] Gol 1.0 Flex 12V 5p, [ano] 2019 Flex, [valor] R$ 40.087,00
#   [model] Gol 1.0 Mi FUN/ Highway/ Sport 16V  2/4p
#   [model] Gol 1.0 Plus 16v 2p
#   [model] Gol 1.0 Plus 16v 4p
#   [model] Gol 1.0 Plus 8v 2p
#   [model] Gol 1.0 Plus 8v 4p
#   [model] Gol 1.0 Power 16v 76cv 4p
#   [model] Gol 1.0 Total Flex 8V 5p (25 Anos)
#   [model] Gol 1.0 Trend/ Power 8V 2p
#   [model] Gol 1.0 Trend/ Power 8V 4p
#   [model] Gol 1.6 I MOTI.Power/Highli T.Flex 8V 4p
#   [model] Gol 1.6 Mi I MOTION Total Flex 8V 3p
#   [model] Gol 1.6 Mi Plus Total Flex 8V 2p
#   [model] Gol 1.6 Mi Plus Total Flex 8V 4p
#   [model] Gol 1.6 Mi Power Total Flex 8V 4p
#   [model] Gol 1.6 Mi Rallye I MOTION T. Flex 8V 4p
#   [model] Gol 1.6 Mi Rallye Total Flex 8V 4p
#   [model] Gol 1.6 Mi/ 1.6i 2p
#   [model] Gol 1.6 Mi/ Power 1.6 Mi 4p
#   [model] Gol 1.6 MSI Flex 16V 5p Aut.
#     [year] 2022 Flex
# [modelo] Gol 1.6 MSI Flex 16V 5p Aut., [ano] 2022 Flex, [valor] R$ 61.003,00
#     [year] 2021 Flex
# [modelo] Gol 1.6 MSI Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 59.515,00
#     [year] 2020 Flex
# [modelo] Gol 1.6 MSI Flex 16V 5p Aut., [ano] 2020 Flex, [valor] R$ 58.063,00
#     [year] 2019 Flex
# [modelo] Gol 1.6 MSI Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 52.675,00
#   [model] Gol 1.6 MSI Flex 8V 5p
#     [year] 2022 Flex
# [modelo] Gol 1.6 MSI Flex 8V 5p, [ano] 2022 Flex, [valor] R$ 57.620,00
#     [year] 2021 Flex
# [modelo] Gol 1.6 MSI Flex 8V 5p, [ano] 2021 Flex, [valor] R$ 51.010,00
#     [year] 2020 Flex
# [modelo] Gol 1.6 MSI Flex 8V 5p, [ano] 2020 Flex, [valor] R$ 47.959,00
#     [year] 2019 Flex
# [modelo] Gol 1.6 MSI Flex 8V 5p, [ano] 2019 Flex, [valor] R$ 44.964,00
#   [model] Gol 1.8 Mi
#   [model] Gol 1.8 Mi 4p
#   [model] Gol 1.8 Mi Power Total Flex 8V 4p
#   [model] Gol 1.8 Mi Rallye Total Flex 8V 4p
#   [model] Gol 1000 (modelo antigo)
#   [model] Gol 1000 Mi 16V 2p Turbo
#   [model] Gol 1000 Mi 16V 4p Turbo
#   [model] Gol 1000 Mi 16V/ Ouro  2p
#   [model] Gol 1000 Mi 16V/ Ouro 4p
#   [model] Gol 1000 Mi 2p  / 1000i
#   [model] Gol 1000 Mi 4p
#   [model] Gol 1000 Mi Plus 16V 2p e 4p
#   [model] Gol 1000 Mi Plus 8v 2p e 4p
#   [model] Gol 1000i Plus 2p
#   [model] Gol 2.0 Mi 2p
#   [model] Gol 2.0 Mi 4p
#   [model] Gol BLACK 1.0 Mi Total Flex 8V 4p
#   [model] Gol City (Trend) 1.0 Mi Total Flex 8V 2p
#   [model] Gol City (Trend) 1.6 Mi T. Flex 8V 2p
#   [model] Gol City (Trend) 1.6 Mi T.Flex 8V 4p
#   [model] Gol City (Trend)/Titan 1.0 T. Flex 8V 4p
#   [model] Gol City 1.0 Mi 8V 2p
#   [model] Gol City 1.0 Mi 8V 4p
#   [model] Gol City 1.0 Total Flex 12V 2p
#   [model] Gol City 1.0 Total Flex 12V 4P
#   [model] Gol City 1.6 Mi 8V 2p
#   [model] Gol City 1.6 Mi 8V 4p
#   [model] Gol CL 1.6 Mi 2p e 4p
#   [model] Gol CL 1.8 Mi 2p e 4p
#   [model] Gol CLi / CL 1.8
#   [model] Gol CLi / CL/ Copa/ Stones 1.6
#   [model] Gol Comfort. I MOTION 1.6 T. Flex 8V 3p
#   [model] Gol Comfort. I MOTION 1.6 T. Flex 8V 5p
#     [year] 2018 Flex
# [modelo] Gol Comfort. I MOTION 1.6 T. Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 45.854,00
#   [model] Gol Comfortline 1.0 T. Flex 12V 5p
#   [model] Gol Comfortline 1.0 T. Flex 8V 3p
#   [model] Gol Comfortline 1.0 T. Flex 8V 5p
#   [model] Gol Comfortline 1.6 T. Flex 8V 3p
#   [model] Gol Comfortline 1.6 T. Flex 8V 5p
#     [year] 2018 Flex
# [modelo] Gol Comfortline 1.6 T. Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 45.785,00
#   [model] Gol COPA 1.0 Mi Total Flex 8V 4p
#   [model] Gol COPA 1.6 Mi Total Flex 8V 4p
#   [model] Gol ECOMOTION  1.0 Mi Total Flex 8V 4p
#   [model] Gol ECOMOTION 1.0 Mi Total Flex 8V 2p
#   [model] Gol Furgao 1.0 mi
#   [model] Gol Furgão 1.6 Mi/ 1.6i/ 1.6
#   [model] Gol GL 1.6 Mi/Star 1.6 e 1.8/Atlanta 1.6
#   [model] Gol GL 1.8 Mi 2p e 4p
#   [model] Gol GLi / GL/ Atlanta 1.8
#   [model] Gol GLS 2.0 Mi
#   [model] Gol GT/GTS 1.8
#   [model] Gol GTi 2.0
#   [model] Gol GTi 2000 16V
#   [model] Gol I MOTION 1.6 Mi Total Flex 8V 4p
#   [model] Gol L 1.3/ L/ LS/ C/ S/ BX/ Plus 1.6
#   [model] Gol Last Edition 1.0 Flex 12V 5p
#     [year] 2023 Flex
# [modelo] Gol Last Edition 1.0 Flex 12V 5p, [ano] 2023 Flex, [valor] R$ 97.979,00
#   [model] Gol Plus 1.0 Mi Total Flex 2p
#   [model] Gol Plus 1.0 Mi Total Flex 4p
#   [model] Gol Rallye 1.6 T. Flex 16V 5p
#   [model] Gol Rallye I MOTION 1.6 T. Flex 16V 5p
#   [model] Gol Rock in Rio 1.0 Mi Total Flex 8V 5p
#   [model] Gol SELEÇÃO 1.0 Mi Total Flex 8V 5p
#   [model] Gol SELEÇÃO 1.6 I MOTION T.Flex 8V 5p
#   [model] Gol SELEÇÃO 1.6 Total Flex 8V 5p
#   [model] Gol Special 1.0 Mi 4p
#   [model] Gol Special 1.0 Total Flex 8V 3p
#   [model] Gol Special 1.0 Total Flex 8V 5p
#   [model] Gol Special 1.6 Mi 8V 99cv 2p
#   [model] Gol Special/ Special Xtreme 1.0 Mi 2p
#   [model] Gol TECH 1.0 Mi Total Flex 8V 2p
#   [model] Gol TECH 1.0 Mi Total Flex 8V 4p
#   [model] Gol TRACK 1.0 Mi Total Flex 8V 4p
#   [model] Gol TRACK 1.0 Total Flex 12V 5p
#     [year] 2018 Flex
# [modelo] Gol TRACK 1.0 Total Flex 12V 5p, [ano] 2018 Flex, [valor] R$ 47.342,00
#   [model] Gol Trendline 1.0 T.Flex 12V 3p
#   [model] Gol Trendline 1.0 T.Flex 12V 5p
#     [year] 2018 Flex
# [modelo] Gol Trendline 1.0 T.Flex 12V 5p, [ano] 2018 Flex, [valor] R$ 41.372,00
#   [model] Gol Trendline 1.0 T.Flex 8V 3p
#   [model] Gol Trendline 1.0 T.Flex 8V 5p
#   [model] Gol Trendline 1.6 T.Flex 8V 3p
#   [model] Gol Trendline 1.6 T.Flex 8V 5p
#     [year] 2018 Flex
# [modelo] Gol Trendline 1.6 T.Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 45.504,00
#   [model] Gol Trendline I Motion 1.6 T. Flex 8V 3p
#   [model] Gol Trendline I MOTION 1.6 T. Flex 8V 5p
#   [model] Gol TSi 1.8/ 1.8Mi
#   [model] Gol TSi 2000 2p e 4p
#   [model] Golf  BLACK EDITON 2.0 Mi T. Flex 8V Tip
#   [model] Golf  TECH 1.6 Mi Total Flex 8V 4p
#   [model] Golf 1.6 Mi Total Flex 8V 4p
#   [model] Golf 1.6 Mi Trip/ Sport 101cv 8V
#   [model] Golf 1.6Mi/ 1.6Mi Gener./Black & Silver
#   [model] Golf 1.8 Mi Sport 150cv Turbo Mec/Aut.
#   [model] Golf 2.0/ 2.0 Mi Flex Aut/Tiptronic.
#   [model] Golf 2.0/ 2.0 Mi Flex Comfortline Aut.
#   [model] Golf 2.0/ 2.0 Mi Flex Comfortline/ Sport
#   [model] Golf 2.0/2.0 T. Flex Mec.(Black & Silv)
#   [model] Golf Comfort. 200 TSI 1.0 Flex 12V Aut.
#     [year] 2018 Flex
# [modelo] Golf Comfort. 200 TSI 1.0 Flex 12V Aut., [ano] 2018 Flex, [valor] R$ 97.940,00
#   [model] Golf Comfortline 1.0 TSI Total Flex Mec.
#   [model] Golf Comfortline 1.4 TSI 140cv Aut.
#   [model] Golf Comfortline 1.4 TSI 140cv Mec.
#   [model] Golf Comfortline 1.6 MSI Total Flex Aut.
#   [model] Golf Comfortline 1.6 MSI Total Flex Mec.
#   [model] Golf Flash 1.6 Mi/1.6 Mi Tot. Flex 8V 4p
#   [model] Golf GL 1.8/ 2.0i 4p
#   [model] Golf GLX 2.0 4p
#   [model] Golf GT 2.0 Mi T. Flex 8V 4p Tiptronic
#   [model] Golf GT 2.0 Mi Total Flex 8V 4p
#   [model] Golf GTE TSI 1.4 16V Híbrido Aut.
#     [year] 2020 Híbrido
# [modelo] Golf GTE TSI 1.4 16V Híbrido Aut., [ano] 2020 Híbrido, [valor] R$ 168.696,00
#   [model] Golf GTi 1.8 Mi 180/193cv Turbo 4p Mec.
#   [model] Golf GTi 1.8 Mi 180/193cv Turbo 4p Tip.
#   [model] Golf GTi 1.8 Mi 20V 2p Turbo Mec.
#   [model] Golf GTi 1.8 Mi 20V Turbo 2p Aut.
#   [model] Golf GTi 1.8 Mi 20V Turbo 4p Aut.
#   [model] Golf GTi 1.8 Mi 20V Turbo 4p Mec.
#   [model] Golf GTI 1.8 Turbo
#   [model] Golf GTi 2.0
#   [model] Golf GTi 2.0 TSI 220cv Aut.
#   [model] Golf GTi 350 TSI 2.0 230cv 16V Aut.
#     [year] 2019 Gasolina
# [modelo] Golf GTi 350 TSI 2.0 230cv 16V Aut., [ano] 2019 Gasolina, [valor] R$ 204.463,00
#     [year] 2018 Gasolina
# [modelo] Golf GTi 350 TSI 2.0 230cv 16V Aut., [ano] 2018 Gasolina, [valor] R$ 175.801,00
#   [model] Golf GTi Cabrio 2.0 Mi
#   [model] Golf GTI VR6/ Golf 2.8 VR6
#   [model] Golf Highline 1.4 TSI 140cv Aut.
#   [model] Golf Highline 1.4 TSI 140cv Mec.
#   [model] Golf Highline 1.4 TSI Total Flex Aut.
#   [model] Golf Highline 1.4 TSI Total Flex Mec.
#   [model] Golf Highline 250 TSI 1.4 Flex 16V Aut.
#     [year] 2018 Flex
# [modelo] Golf Highline 250 TSI 1.4 Flex 16V Aut., [ano] 2018 Flex, [valor] R$ 114.453,00
#   [model] Golf SILVER EDIT. 2.0 Mi T.Flex 8v Mec.
#   [model] Golf SILVER EDIT. 2.0 Mi T.Flex 8V Tip.
#   [model] Golf Sportline 1.6 Mi Total Flex 8V 4p
#   [model] Golf Sportline 2.0 Mi Total F. 8V Tip.
#   [model] Golf Variant Comf. 250 1.4 TSI Flex Aut.
#     [year] 2018 Flex
# [modelo] Golf Variant Comf. 250 1.4 TSI Flex Aut., [ano] 2018 Flex, [valor] R$ 99.499,00
#   [model] Golf Variant Comfort. 1.4 TSI T.Flex Aut
#   [model] Golf Variant Comfortline 1.4 TSI  Aut.
#   [model] Golf Variant Comfortline 1.4 TSI Mec.
#   [model] Golf Variant High. 250 1.4 TSI Flex Aut.
#     [year] 2018 Flex
# [modelo] Golf Variant High. 250 1.4 TSI Flex Aut., [ano] 2018 Flex, [valor] R$ 115.812,00
#   [model] Golf Variant Highli. 1.4 TSI T.Flex Aut
#   [model] Golf Variant Highline 1.4 TSI Aut.
#   [model_lbl] polo
#   [model] Apolo GL 1.8
#   [model] Apolo GLS/ Vip 1.8
#   [model] Polo 1.0 Flex 12V 5p
#     [year] 2022 Flex
# [modelo] Polo 1.0 Flex 12V 5p, [ano] 2022 Flex, [valor] R$ 70.829,00
#     [year] 2021 Flex
# [modelo] Polo 1.0 Flex 12V 5p, [ano] 2021 Flex, [valor] R$ 67.036,00
#     [year] 2020 Flex
# [modelo] Polo 1.0 Flex 12V 5p, [ano] 2020 Flex, [valor] R$ 63.382,00
#     [year] 2019 Flex
# [modelo] Polo 1.0 Flex 12V 5p, [ano] 2019 Flex, [valor] R$ 61.836,00
#     [year] 2018 Flex
# [modelo] Polo 1.0 Flex 12V 5p, [ano] 2018 Flex, [valor] R$ 59.880,00
#   [model] Polo 1.0 Mi 79cv 16V 5p
#   [model] Polo 1.0 MPI Flex 12V 5p
#     [year] 2026 Flex
# [modelo] Polo 1.0 MPI Flex 12V 5p, [ano] 2026 Flex, [valor] R$ 83.035,00
#     [year] 2025 Flex
# [modelo] Polo 1.0 MPI Flex 12V 5p, [ano] 2025 Flex, [valor] R$ 76.683,00
#     [year] 2024 Flex
# [modelo] Polo 1.0 MPI Flex 12V 5p, [ano] 2024 Flex, [valor] R$ 74.153,00
#     [year] 2023 Flex
# [modelo] Polo 1.0 MPI Flex 12V 5p, [ano] 2023 Flex, [valor] R$ 69.811,00
#   [model] Polo 1.0 TSI Flex 12V 5p
#     [year] 2026 Flex
# [modelo] Polo 1.0 TSI Flex 12V 5p, [ano] 2026 Flex, [valor] R$ 107.210,00
#     [year] 2025 Flex
# [modelo] Polo 1.0 TSI Flex 12V 5p, [ano] 2025 Flex, [valor] R$ 93.294,00
#     [year] 2024 Flex
# [modelo] Polo 1.0 TSI Flex 12V 5p, [ano] 2024 Flex, [valor] R$ 79.858,00
#     [year] 2023 Flex
# [modelo] Polo 1.0 TSI Flex 12V 5p, [ano] 2023 Flex, [valor] R$ 76.834,00
#   [model] Polo 1.6 E-Flex 8V 5p
#   [model] Polo 1.6 Mi/ S.Ouro 1.6Mi 101cv 8V 5p
#   [model] Polo 1.6 Mi/S.Ouro 1.6 Mi Tot.Flex 8V 5p
#   [model] Polo 1.6 MSI Flex 16V 5p
#     [year] 2022 Flex
# [modelo] Polo 1.6 MSI Flex 16V 5p, [ano] 2022 Flex, [valor] R$ 73.577,00
#     [year] 2021 Flex
# [modelo] Polo 1.6 MSI Flex 16V 5p, [ano] 2021 Flex, [valor] R$ 69.939,00
#     [year] 2020 Flex
# [modelo] Polo 1.6 MSI Flex 16V 5p, [ano] 2020 Flex, [valor] R$ 65.823,00
#     [year] 2019 Flex
# [modelo] Polo 1.6 MSI Flex 16V 5p, [ano] 2019 Flex, [valor] R$ 64.217,00
#     [year] 2018 Flex
# [modelo] Polo 1.6 MSI Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 59.698,00
#   [model] Polo 1.6 MSI Total Flex 16V 5p Aut.
#     [year] 2022 Flex
# [modelo] Polo 1.6 MSI Total Flex 16V 5p Aut., [ano] 2022 Flex, [valor] R$ 75.507,00
#     [year] 2021 Flex
# [modelo] Polo 1.6 MSI Total Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 70.731,00
#     [year] 2020 Flex
# [modelo] Polo 1.6 MSI Total Flex 16V 5p Aut., [ano] 2020 Flex, [valor] R$ 66.501,00
#     [year] 2019 Flex
# [modelo] Polo 1.6 MSI Total Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 64.879,00
#   [model] Polo 2.0 Mi 116cv 8V 5p
#   [model] Polo BLUEMOTION 1.6 Total Flex 8V 5p
#   [model] Polo Classic 1.0 Mi 16v  65cv 4p
#   [model] Polo Classic/ Special 1.8 Mi
#   [model] Polo Comfort. 200 TSI 1.0 Flex 12V Aut.
#     [year] 2022 Flex
# [modelo] Polo Comfort. 200 TSI 1.0 Flex 12V Aut., [ano] 2022 Flex, [valor] R$ 85.934,00
#     [year] 2021 Flex
# [modelo] Polo Comfort. 200 TSI 1.0 Flex 12V Aut., [ano] 2021 Flex, [valor] R$ 79.187,00
#     [year] 2020 Flex
# [modelo] Polo Comfort. 200 TSI 1.0 Flex 12V Aut., [ano] 2020 Flex, [valor] R$ 74.688,00
#     [year] 2019 Flex
# [modelo] Polo Comfort. 200 TSI 1.0 Flex 12V Aut., [ano] 2019 Flex, [valor] R$ 71.355,00
#     [year] 2018 Flex
# [modelo] Polo Comfort. 200 TSI 1.0 Flex 12V Aut., [ano] 2018 Flex, [valor] R$ 69.614,00
#   [model] Polo Comfortline TSI 1.0 Flex 12V Aut.
#     [year] 2026 Flex
# [modelo] Polo Comfortline TSI 1.0 Flex 12V Aut., [ano] 2026 Flex, [valor] R$ 107.829,00
#     [year] 2025 Flex
# [modelo] Polo Comfortline TSI 1.0 Flex 12V Aut., [ano] 2025 Flex, [valor] R$ 99.517,00
#     [year] 2024 Flex
# [modelo] Polo Comfortline TSI 1.0 Flex 12V Aut., [ano] 2024 Flex, [valor] R$ 89.319,00
#     [year] 2023 Flex
# [modelo] Polo Comfortline TSI 1.0 Flex 12V Aut., [ano] 2023 Flex, [valor] R$ 84.306,00
#   [model] Polo GT 2.0 Mi Total Flex 8V 5p
#   [model] Polo GTI 1.8 Mi 150cv 20V Turbo 3p
#   [model] Polo GTS 1.4 TSI 16V Flex
#     [year] 2025 Flex
# [modelo] Polo GTS 1.4 TSI 16V Flex, [ano] 2025 Flex, [valor] R$ 136.276,00
#     [year] 2024 Flex
# [modelo] Polo GTS 1.4 TSI 16V Flex, [ano] 2024 Flex, [valor] R$ 124.214,00
#     [year] 2023 Flex
# [modelo] Polo GTS 1.4 TSI 16V Flex, [ano] 2023 Flex, [valor] R$ 119.014,00
#     [year] 2022 Flex
# [modelo] Polo GTS 1.4 TSI 16V Flex, [ano] 2022 Flex, [valor] R$ 110.312,00
#     [year] 2021 Flex
# [modelo] Polo GTS 1.4 TSI 16V Flex, [ano] 2021 Flex, [valor] R$ 107.255,00
#     [year] 2020 Flex
# [modelo] Polo GTS 1.4 TSI 16V Flex, [ano] 2020 Flex, [valor] R$ 100.208,00
#   [model] Polo Highline 200 TSI 1.0 Flex 12V Aut.
#     [year] 2022 Flex
# [modelo] Polo Highline 200 TSI 1.0 Flex 12V Aut., [ano] 2022 Flex, [valor] R$ 89.324,00
#     [year] 2021 Flex
# [modelo] Polo Highline 200 TSI 1.0 Flex 12V Aut., [ano] 2021 Flex, [valor] R$ 85.445,00
#     [year] 2020 Flex
# [modelo] Polo Highline 200 TSI 1.0 Flex 12V Aut., [ano] 2020 Flex, [valor] R$ 81.705,00
#     [year] 2019 Flex
# [modelo] Polo Highline 200 TSI 1.0 Flex 12V Aut., [ano] 2019 Flex, [valor] R$ 79.712,00
#     [year] 2018 Flex
# [modelo] Polo Highline 200 TSI 1.0 Flex 12V Aut., [ano] 2018 Flex, [valor] R$ 75.406,00
#   [model] Polo Highline TSI 1.0 Flex 12V Aut.
#     [year] 2026 Flex
# [modelo] Polo Highline TSI 1.0 Flex 12V Aut., [ano] 2026 Flex, [valor] R$ 114.509,00
#     [year] 2025 Flex
# [modelo] Polo Highline TSI 1.0 Flex 12V Aut., [ano] 2025 Flex, [valor] R$ 107.636,00
#     [year] 2024 Flex
# [modelo] Polo Highline TSI 1.0 Flex 12V Aut., [ano] 2024 Flex, [valor] R$ 97.965,00
#     [year] 2023 Flex
# [modelo] Polo Highline TSI 1.0 Flex 12V Aut., [ano] 2023 Flex, [valor] R$ 94.627,00
#   [model] Polo I MOTION 1.6 Total Flex  5p
#   [model] Polo Next 1.6 Mi 101cv 8V 5p
#   [model] Polo Robust 1.0 Flex 12V 5p
#     [year] 2026 Flex
# [modelo] Polo Robust 1.0 Flex 12V 5p, [ano] 2026 Flex, [valor] R$ 83.390,00
#     [year] 2025 Flex
# [modelo] Polo Robust 1.0 Flex 12V 5p, [ano] 2025 Flex, [valor] R$ 79.251,00
#   [model] Polo Sed. COMFORT. 1.6 Mi Tot. Flex 8v
#   [model] Polo Sed./Sed. COMF. 2.0/2.0 Flex 8V 4p
#   [model] Polo Sed.COMFORT. I MOTION 1.6 T.Flex 4p
#   [model] Polo Sedan 1.6 Mi 101cv 8V 4p
#   [model] Polo Sedan 1.6 Mi Total Flex 8V 4p
#   [model] Polo Sedan Evidence 1.6 Mi T.Flex 8v 4p
#   [model] Polo Sedan I MOTION  1.6 Total Flex  4p
#   [model] Polo Sense TSI 1.0 Flex 12V Aut
#     [year] 2026 Flex
# [modelo] Polo Sense TSI 1.0 Flex 12V Aut, [ano] 2026 Flex, [valor] R$ 97.589,00
#     [year] 2025 Flex
# [modelo] Polo Sense TSI 1.0 Flex 12V Aut, [ano] 2025 Flex, [valor] R$ 91.869,00
#     [year] 2024 Flex
# [modelo] Polo Sense TSI 1.0 Flex 12V Aut, [ano] 2024 Flex, [valor] R$ 81.183,00
#     [year] 2021 Flex
# [modelo] Polo Sense TSI 1.0 Flex 12V Aut, [ano] 2021 Flex, [valor] R$ 75.952,00
#     [year] 2020 Flex
# [modelo] Polo Sense TSI 1.0 Flex 12V Aut, [ano] 2020 Flex, [valor] R$ 73.757,00
#     [year] 2019 Flex
# [modelo] Polo Sense TSI 1.0 Flex 12V Aut, [ano] 2019 Flex, [valor] R$ 69.448,00
#   [model] Polo SPORTLINE 1.6 Mi Total Flex 8V 5p
#   [model] Polo Sportline 2.0 Mi Total Flex 8V 5p
#   [model] Polo SPORTLINE I MOTION 1.6 T.Flex 5p
#   [model] Polo Track 1.0 Flex 12V 5p
#     [year] 2026 Flex
# [modelo] Polo Track 1.0 Flex 12V 5p, [ano] 2026 Flex, [valor] R$ 80.825,00
#     [year] 2025 Flex
# [modelo] Polo Track 1.0 Flex 12V 5p, [ano] 2025 Flex, [valor] R$ 76.026,00
#     [year] 2024 Flex
# [modelo] Polo Track 1.0 Flex 12V 5p, [ano] 2024 Flex, [valor] R$ 69.610,00
#     [year] 2023 Flex
# [modelo] Polo Track 1.0 Flex 12V 5p, [ano] 2023 Flex, [valor] R$ 66.393,00
#   [model] Polo Track First Edition 1.0 Flex 12V 5p
#     [year] 2023 Flex
# [modelo] Polo Track First Edition 1.0 Flex 12V 5p, [ano] 2023 Flex, [valor] R$ 76.068,00
#   [model] Polo Track Rock in Rio 1.0 Flex 12V 5p
#     [year] 2025 Flex
# [modelo] Polo Track Rock in Rio 1.0 Flex 12V 5p, [ano] 2025 Flex, [valor] R$ 79.020,00
#   [model_lbl] voyage
#   [model] VOYAGE  Trendline 1.0 T.Flex 8V 4p
#   [model] VOYAGE 1.0 Flex 12V 4p
#     [year] 2023 Flex
# [modelo] VOYAGE 1.0 Flex 12V 4p, [ano] 2023 Flex, [valor] R$ 60.211,00
#     [year] 2022 Flex
# [modelo] VOYAGE 1.0 Flex 12V 4p, [ano] 2022 Flex, [valor] R$ 54.721,00
#     [year] 2021 Flex
# [modelo] VOYAGE 1.0 Flex 12V 4p, [ano] 2021 Flex, [valor] R$ 49.278,00
#     [year] 2020 Flex
# [modelo] VOYAGE 1.0 Flex 12V 4p, [ano] 2020 Flex, [valor] R$ 44.321,00
#     [year] 2019 Flex
# [modelo] VOYAGE 1.0 Flex 12V 4p, [ano] 2019 Flex, [valor] R$ 43.240,00
#   [model] VOYAGE 1.0/1.0 City Mi Total Flex 8V 4p
#   [model] VOYAGE 1.6 MSI Flex 16V 4p Aut.
#     [year] 2022 Flex
# [modelo] VOYAGE 1.6 MSI Flex 16V 4p Aut., [ano] 2022 Flex, [valor] R$ 65.222,00
#     [year] 2021 Flex
# [modelo] VOYAGE 1.6 MSI Flex 16V 4p Aut., [ano] 2021 Flex, [valor] R$ 62.375,00
#     [year] 2020 Flex
# [modelo] VOYAGE 1.6 MSI Flex 16V 4p Aut., [ano] 2020 Flex, [valor] R$ 60.853,00
#     [year] 2019 Flex
# [modelo] VOYAGE 1.6 MSI Flex 16V 4p Aut., [ano] 2019 Flex, [valor] R$ 59.368,00
#   [model] VOYAGE 1.6 MSI Flex 8V 4p
#     [year] 2022 Flex
# [modelo] VOYAGE 1.6 MSI Flex 8V 4p, [ano] 2022 Flex, [valor] R$ 60.022,00
#     [year] 2021 Flex
# [modelo] VOYAGE 1.6 MSI Flex 8V 4p, [ano] 2021 Flex, [valor] R$ 49.727,00
#     [year] 2020 Flex
# [modelo] VOYAGE 1.6 MSI Flex 8V 4p, [ano] 2020 Flex, [valor] R$ 48.514,00
#     [year] 2019 Flex
# [modelo] VOYAGE 1.6 MSI Flex 8V 4p, [ano] 2019 Flex, [valor] R$ 47.330,00
#   [model] VOYAGE 1.6/1.6 City  Mi Total Flex 8V 4p
#   [model] VOYAGE C/CL/Fox 1.6
#   [model] VOYAGE CL 1.8
#   [model] VOYAGE COMF/Highli. 1.6 T.Flex 8V 4p
#     [year] 2018 Flex
# [modelo] VOYAGE COMF/Highli. 1.6 T.Flex 8V 4p, [ano] 2018 Flex, [valor] R$ 48.560,00
#   [model] VOYAGE Comfortline  1.0 T.Flex 8V 4p
#   [model] VOYAGE Comfortline 1.0 T.Flex 12V 4p
#     [year] 2018 Flex
# [modelo] VOYAGE Comfortline 1.0 T.Flex 12V 4p, [ano] 2018 Flex, [valor] R$ 49.313,00
#   [model] VOYAGE Evidence 1.6 Total Flex 8V 4p
#   [model] VOYAGE GL 1.8 4p (Argentino)
#   [model] VOYAGE GL/ Special 1.6/ 1.8
#   [model] VOYAGE I MOTION  Trendline 1.6 T.Flex 8V
#   [model] VOYAGE I MOTION 1.6 Mi Total Flex 8V
#   [model] VOYAGE I MOTION COMF/Hghli.1.6 T.Flex 8V
#     [year] 2018 Flex
# [modelo] VOYAGE I MOTION COMF/Hghli.1.6 T.Flex 8V, [ano] 2018 Flex, [valor] R$ 50.100,00
#   [model] VOYAGE I MOTION Evidence 1.6 T.Flex 8V
#   [model] VOYAGE I MOTION TREND 1.6 Mi T. Flex 8V
#   [model] VOYAGE L/LS/Plus/GLS/S/Sport/Super L.Ang
#   [model] VOYAGE SELEÇÃO 1.0 Mi Total Flex 8V 4p
#   [model] VOYAGE SELEÇÃO 1.6 I MOTION T.Flex 8V 4p
#   [model] VOYAGE SELEÇÃO 1.6 Total Flex 8V 4p
#   [model] VOYAGE TREND 1.6 Mi Total Flex 8V 4p
#   [model] VOYAGE Trendline 1.0 T.Flex 12V 4p
#     [year] 2018 Flex
# [modelo] VOYAGE Trendline 1.0 T.Flex 12V 4p, [ano] 2018 Flex, [valor] R$ 43.032,00
#   [model] VOYAGE Trendline 1.6 T.Flex 8V 4p
#     [year] 2018 Flex
# [modelo] VOYAGE Trendline 1.6 T.Flex 8V 4p, [ano] 2018 Flex, [valor] R$ 43.720,00
#   [model_lbl] fox
#   [model] CROSSFOX  1.6 T. Flex 16V 5p
#     [year] 2018 Flex
# [modelo] CROSSFOX  1.6 T. Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 59.742,00
#   [model] CROSSFOX  I MOTION 1.6 T. Flex 16V 5p
#     [year] 2018 Flex
# [modelo] CROSSFOX  I MOTION 1.6 T. Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 62.717,00
#   [model] CROSSFOX 1.6 Mi Total Flex 8V 5p
#   [model] CROSSFOX I MOTION 1.6 Mi T. Flex 8V 5p
#   [model] Fox 1.0 Mi Total Flex 8V 3p
#   [model] Fox 1.0 Mi Total Flex 8V 5p
#   [model] Fox 1.6 Mi I MOTION Total Flex 8V 5p
#   [model] Fox 1.6 Mi Total Flex 8V 5p
#   [model] Fox BLUEMOTION 1.0 Mi Total Flex 12V 3p
#   [model] Fox BLUEMOTION 1.0 Mi Total Flex 12V 5p
#   [model] Fox BlueMotion 1.6 Mi Total Flex 3p.
#   [model] Fox BlueMotion 1.6 Mi Total Flex 5p.
#   [model] Fox City 1.0 Mi/ 1.0Mi Total Flex 8V 5p
#   [model] Fox City 1.0Mi/ 1.0Mi Total Flex 8V 3p
#   [model] Fox Comfortline 1.0 Flex 12V 5p
#   [model] Fox Comfortline 1.0 Flex 8V 5p
#   [model] Fox Comfortline 1.6 Flex 8V 5p
#     [year] 2018 Flex
# [modelo] Fox Comfortline 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 53.182,00
#   [model] Fox Comfortline I Motion 1.6 Flex 8V 5p
#     [year] 2018 Flex
# [modelo] Fox Comfortline I Motion 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 53.487,00
#   [model] Fox Connect 1.6 Flex 8V 5p
#     [year] 2022 Flex
# [modelo] Fox Connect 1.6 Flex 8V 5p, [ano] 2022 Flex, [valor] R$ 65.619,00
#     [year] 2021 Flex
# [modelo] Fox Connect 1.6 Flex 8V 5p, [ano] 2021 Flex, [valor] R$ 62.333,00
#     [year] 2020 Flex
# [modelo] Fox Connect 1.6 Flex 8V 5p, [ano] 2020 Flex, [valor] R$ 60.812,00
#     [year] 2019 Flex
# [modelo] Fox Connect 1.6 Flex 8V 5p, [ano] 2019 Flex, [valor] R$ 55.678,00
#     [year] 2018 Flex
# [modelo] Fox Connect 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 53.326,00
#   [model] Fox Connect I Motion 1.6 Flex 8V 5p
#     [year] 2019 Flex
# [modelo] Fox Connect I Motion 1.6 Flex 8V 5p, [ano] 2019 Flex, [valor] R$ 56.021,00
#     [year] 2018 Flex
# [modelo] Fox Connect I Motion 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 54.621,00
#   [model] Fox extreme 1.6 Mi Total Flex 8V 5p
#   [model] Fox Highline I MOTION 1.6 Flex 16V 5p
#     [year] 2018 Flex
# [modelo] Fox Highline I MOTION 1.6 Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 55.490,00
#   [model] Fox Highline1.6 Flex 16V 5p
#     [year] 2018 Flex
# [modelo] Fox Highline1.6 Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 55.159,00
#   [model] Fox PEPPER 1.6 Flex 16V 5p
#     [year] 2018 Flex
# [modelo] Fox PEPPER 1.6 Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 59.227,00
#   [model] Fox PEPPER I MOTION 1.6 Flex 16V 5p
#     [year] 2018 Flex
# [modelo] Fox PEPPER I MOTION 1.6 Flex 16V 5p, [ano] 2018 Flex, [valor] R$ 61.114,00
#   [model] Fox Plus 1.0Mi/ 1.0Mi Total Flex 8V 3p
#   [model] Fox Plus 1.0Mi/ 1.0Mi Total Flex 8V 4p
#   [model] Fox Plus 1.6Mi/ 1.6Mi Total Flex 8V 3p
#   [model] Fox Plus 1.6Mi/ 1.6Mi Total Flex 8V 4p
#   [model] Fox PRIME/Hghi. IMOTION 1.6 T.Flex 8V 5p
#   [model] Fox PRIME/Higli. 1.6 Total Flex 8V 5p
#   [model] Fox Rock in Rio 1.6 Mi Total Flex 8V 5p
#   [model] Fox Route 1.0 Mi Total Flex 8V 3p
#   [model] Fox Route 1.0 Mi Total Flex 8V 5p
#   [model] Fox Route 1.6 Mi Total Flex 8V 3p
#   [model] Fox Route 1.6 Mi Total Flex 8V 5p
#   [model] Fox RUN 1.6 Flex 8V 5p
#   [model] Fox SELEÇÃO 1.0 Total Flex 8V 5p
#   [model] Fox SELEÇÃO 1.6 Total Flex 8V 5p
#   [model] Fox SELEÇÃO IMOTION 1.6 Mi T. Flex 8V 5p
#   [model] Fox Sportline/Sports 1.0 Tot.Flex 8V 4p
#   [model] Fox Sportline/Sports 1.0/1.0 Tot.Flex 3p
#   [model] Fox Sportline/Sports 1.6/1.6 Tot.Flex 3p
#   [model] Fox Sportline/Sports 1.6/1.6 Tot.Flex 4p
#   [model] Fox SUNRISE 1.0 Mi Total Flex 8V 5p
#   [model] Fox TRACK 1.0 Flex 12V 5p
#     [year] 2018 Flex
# [modelo] Fox TRACK 1.0 Flex 12V 5p, [ano] 2018 Flex, [valor] R$ 55.746,00
#   [model] Fox Trendline 1.0 Flex 12V 5p
#     [year] 2018 Flex
# [modelo] Fox Trendline 1.0 Flex 12V 5p, [ano] 2018 Flex, [valor] R$ 52.374,00
#   [model] Fox Trendline 1.0 Flex 8V 5p
#   [model] Fox Trendline 1.6 Flex 8V 5p
#     [year] 2018 Flex
# [modelo] Fox Trendline 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 54.453,00
#   [model] Fox Xtreme 1.6 Flex 8V 5p
#     [year] 2022 Flex
# [modelo] Fox Xtreme 1.6 Flex 8V 5p, [ano] 2022 Flex, [valor] R$ 70.398,00
#     [year] 2021 Flex
# [modelo] Fox Xtreme 1.6 Flex 8V 5p, [ano] 2021 Flex, [valor] R$ 67.837,00
#     [year] 2020 Flex
# [modelo] Fox Xtreme 1.6 Flex 8V 5p, [ano] 2020 Flex, [valor] R$ 63.742,00
#     [year] 2019 Flex
# [modelo] Fox Xtreme 1.6 Flex 8V 5p, [ano] 2019 Flex, [valor] R$ 61.480,00
#     [year] 2018 Flex
# [modelo] Fox Xtreme 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 59.980,00
#   [model] SPACEFOX  SPORTLINE/HIGHLINE 1.6 T.Flex
#   [model] SPACEFOX  TREND I MOTION 1.6 T. Flex 8V
#   [model] SPACEFOX 1.6 Trendline I MOT. T.Flex 8V
#     [year] 2019 Flex
# [modelo] SPACEFOX 1.6 Trendline I MOT. T.Flex 8V, [ano] 2019 Flex, [valor] R$ 53.632,00
#     [year] 2018 Flex
# [modelo] SPACEFOX 1.6 Trendline I MOT. T.Flex 8V, [ano] 2018 Flex, [valor] R$ 51.062,00
#   [model] SPACEFOX 1.6 Trendline Total Flex 8v 5p
#     [year] 2019 Flex
# [modelo] SPACEFOX 1.6 Trendline Total Flex 8v 5p, [ano] 2019 Flex, [valor] R$ 51.972,00
#     [year] 2018 Flex
# [modelo] SPACEFOX 1.6 Trendline Total Flex 8v 5p, [ano] 2018 Flex, [valor] R$ 50.436,00
#   [model] SPACEFOX 1.6/ 1.6 Trend Total Flex 8V 5p
#   [model] SPACEFOX COMF. I MOTION 1.6 Flex 8V 5p
#     [year] 2018 Flex
# [modelo] SPACEFOX COMF. I MOTION 1.6 Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 56.087,00
#   [model] SPACEFOX COMFORTLINE 1.6 Mi T.Flex 8V 5p
#     [year] 2018 Flex
# [modelo] SPACEFOX COMFORTLINE 1.6 Mi T.Flex 8V 5p, [ano] 2018 Flex, [valor] R$ 55.361,00
#   [model] SPACEFOX HIGHLINE 1.6 T.Flex 16V
#     [year] 2018 Flex
# [modelo] SPACEFOX HIGHLINE 1.6 T.Flex 16V, [ano] 2018 Flex, [valor] R$ 56.309,00
#   [model] SPACEFOX HIGHLINE I MOT. 1.6 T.Flex 16V
#     [year] 2018 Flex
# [modelo] SPACEFOX HIGHLINE I MOT. 1.6 T.Flex 16V, [ano] 2018 Flex, [valor] R$ 56.422,00
#   [model] SPACEFOX Route 1.6 Mi T.Flex 5p
#   [model] SPACEFOX SPORTLINE/HIGHLINE I MOTION 1.6
#   [model] VOYAGE C/CL/Fox 1.6
#   [model_lbl] saveiro
#   [model] Grand Saveiro Xtreme/Street  1.6/1.8/2.0
#   [model] Saveiro 1.6 Mi Total Flex 8V CE
#   [model] Saveiro 1.6 Mi/ 1.6 Mi Total Flex 8V
#   [model] Saveiro 1.6 Mi/ 1.6Mi City Total Flex 8V
#   [model] Saveiro 1.8 Mi
#   [model] Saveiro 2.0 Mi
#   [model] Saveiro City 1.8 Mi Total Flex 8V
#   [model] Saveiro CL 1.6 Mi / CL/ C 1.6
#   [model] Saveiro CL/ Summer 1.8 Mi e 1.8
#   [model] Saveiro CROSS 1.6 Mi Total Flex 8V CE
#   [model] Saveiro CROSS 1.6 T. Flex 16V CE
#     [year] 2018 Flex
# [modelo] Saveiro CROSS 1.6 T. Flex 16V CE, [ano] 2018 Flex, [valor] R$ 79.786,00
#   [model] Saveiro CROSS 1.6 T.Flex 16V CD
#     [year] 2023 Flex
# [modelo] Saveiro CROSS 1.6 T.Flex 16V CD, [ano] 2023 Flex, [valor] R$ 92.417,00
#     [year] 2022 Flex
# [modelo] Saveiro CROSS 1.6 T.Flex 16V CD, [ano] 2022 Flex, [valor] R$ 88.635,00
#     [year] 2021 Flex
# [modelo] Saveiro CROSS 1.6 T.Flex 16V CD, [ano] 2021 Flex, [valor] R$ 86.033,00
#     [year] 2020 Flex
# [modelo] Saveiro CROSS 1.6 T.Flex 16V CD, [ano] 2020 Flex, [valor] R$ 83.934,00
#     [year] 2019 Flex
# [modelo] Saveiro CROSS 1.6 T.Flex 16V CD, [ano] 2019 Flex, [valor] R$ 81.886,00
#     [year] 2018 Flex
# [modelo] Saveiro CROSS 1.6 T.Flex 16V CD, [ano] 2018 Flex, [valor] R$ 79.888,00
#   [model] Saveiro CROSSOVER 1.6 Mi Total Flex 8V
#   [model] Saveiro CROSSOVER 1.8 Mi 8V
#   [model] Saveiro CROSSOVER 1.8 Mi Total Flex 8V
#   [model] Saveiro Diesel (todas)
#   [model] Saveiro Extreme 1.6 Flex 16V CD
#     [year] 2026 Flex
# [modelo] Saveiro Extreme 1.6 Flex 16V CD, [ano] 2026 Flex, [valor] R$ 116.924,00
#     [year] 2025 Flex
# [modelo] Saveiro Extreme 1.6 Flex 16V CD, [ano] 2025 Flex, [valor] R$ 108.692,00
#     [year] 2024 Flex
# [modelo] Saveiro Extreme 1.6 Flex 16V CD, [ano] 2024 Flex, [valor] R$ 103.722,00
#   [model] Saveiro FUN 1.8 99cv/ City e S.Surf  1.6
#   [model] Saveiro GL 1.8Mi e 1.6/GL/LS/S/ Sunset
#   [model] Saveiro Highline 1.6 T. Flex 8V CD
#     [year] 2018 Flex
# [modelo] Saveiro Highline 1.6 T. Flex 8V CD, [ano] 2018 Flex, [valor] R$ 73.000,00
#   [model] Saveiro Pepper 1.6 Flex 8V CD
#     [year] 2019 Flex
# [modelo] Saveiro Pepper 1.6 Flex 8V CD, [ano] 2019 Flex, [valor] R$ 73.973,00
#     [year] 2018 Flex
# [modelo] Saveiro Pepper 1.6 Flex 8V CD, [ano] 2018 Flex, [valor] R$ 72.168,00
#   [model] Saveiro Pepper 1.6 Flex 8V CE
#     [year] 2019 Flex
# [modelo] Saveiro Pepper 1.6 Flex 8V CE, [ano] 2019 Flex, [valor] R$ 72.791,00
#     [year] 2018 Flex
# [modelo] Saveiro Pepper 1.6 Flex 8V CE, [ano] 2018 Flex, [valor] R$ 70.536,00
#   [model] Saveiro Robust 1.6 Total Flex 16V
#     [year] 2026 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V , [ano] 2026 Flex, [valor] R$ 90.969,00
#     [year] 2025 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V , [ano] 2025 Flex, [valor] R$ 85.986,00
#     [year] 2024 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V , [ano] 2024 Flex, [valor] R$ 77.920,00
#     [year] 2023 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V , [ano] 2023 Flex, [valor] R$ 67.940,00
#   [model] Saveiro Robust 1.6 Total Flex 16V CD
#     [year] 2026 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V CD, [ano] 2026 Flex, [valor] R$ 99.065,00
#     [year] 2025 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V CD, [ano] 2025 Flex, [valor] R$ 88.887,00
#     [year] 2024 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V CD, [ano] 2024 Flex, [valor] R$ 78.912,00
#     [year] 2023 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 16V CD, [ano] 2023 Flex, [valor] R$ 73.960,00
#   [model] Saveiro Robust 1.6 Total Flex 8V
#     [year] 2023 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V, [ano] 2023 Flex, [valor] R$ 69.157,00
#     [year] 2022 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V, [ano] 2022 Flex, [valor] R$ 62.774,00
#     [year] 2021 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V, [ano] 2021 Flex, [valor] R$ 60.469,00
#     [year] 2020 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V, [ano] 2020 Flex, [valor] R$ 53.792,00
#     [year] 2019 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V, [ano] 2019 Flex, [valor] R$ 52.480,00
#     [year] 2018 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V, [ano] 2018 Flex, [valor] R$ 49.707,00
#   [model] Saveiro Robust 1.6 Total Flex 8V CD
#     [year] 2023 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V CD, [ano] 2023 Flex, [valor] R$ 73.955,00
#     [year] 2022 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V CD, [ano] 2022 Flex, [valor] R$ 70.372,00
#     [year] 2021 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V CD, [ano] 2021 Flex, [valor] R$ 67.679,00
#     [year] 2020 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V CD, [ano] 2020 Flex, [valor] R$ 65.521,00
#     [year] 2019 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V CD, [ano] 2019 Flex, [valor] R$ 62.806,00
#     [year] 2018 Flex
# [modelo] Saveiro Robust 1.6 Total Flex 8V CD, [ano] 2018 Flex, [valor] R$ 61.274,00
#   [model] Saveiro Rock in Rio 1.6 Total Flex 8V CD
#   [model] Saveiro SPORTLINE 1.6 Mi Total Flex 8V
#   [model] Saveiro SPORTLINE 1.8 Mi Total Flex 8V
#   [model] Saveiro Startline 1.6 T.Flex 8V
#   [model] Saveiro Super Surf  1.8 Mi 8V 99cv
#   [model] Saveiro Super Surf 1.6 Mi Total Flex 8V
#   [model] Saveiro Super Surf 1.8 Mi Total Flex 8V
#   [model] Saveiro SURF 1.6 Mi Total Flex 2p
#   [model] Saveiro SURF 1.8 Mi Total Flex 2p
#   [model] Saveiro TITAN  1.6 Mi Total Flex 2p
#   [model] Saveiro Trendline 1.6 T.Flex 8V
#     [year] 2022 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V, [ano] 2022 Flex, [valor] R$ 68.159,00
#     [year] 2021 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V, [ano] 2021 Flex, [valor] R$ 66.266,00
#     [year] 2020 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V, [ano] 2020 Flex, [valor] R$ 61.556,00
#     [year] 2019 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V, [ano] 2019 Flex, [valor] R$ 58.882,00
#     [year] 2018 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V, [ano] 2018 Flex, [valor] R$ 56.962,00
#   [model] Saveiro Trendline 1.6 T.Flex 8V CD
#     [year] 2018 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V CD, [ano] 2018 Flex, [valor] R$ 61.461,00
#   [model] Saveiro Trendline 1.6 T.Flex 8V CE
#     [year] 2018 Flex
# [modelo] Saveiro Trendline 1.6 T.Flex 8V CE, [ano] 2018 Flex, [valor] R$ 60.653,00
#   [model] Saveiro Trendline 1.6 Total Flex 16V
#     [year] 2026 Flex
# [modelo] Saveiro Trendline 1.6 Total Flex 16V, [ano] 2026 Flex, [valor] R$ 104.989,00
#     [year] 2025 Flex
# [modelo] Saveiro Trendline 1.6 Total Flex 16V, [ano] 2025 Flex, [valor] R$ 94.674,00
#     [year] 2024 Flex
# [modelo] Saveiro Trendline 1.6 Total Flex 16V, [ano] 2024 Flex, [valor] R$ 83.522,00
#     [year] 2023 Flex
# [modelo] Saveiro Trendline 1.6 Total Flex 16V, [ano] 2023 Flex, [valor] R$ 77.271,00
#   [model] Saveiro TROOPER 1.6 Mi Total Flex 8V
#   [model] Saveiro TROOPER 1.6 Mi Total Flex 8V CE
#   [model] Saveiro TSi 2.0 Mi
# [brand] GM - Chevrolet
#   [model_lbl] onix
#   [model] ONIX  Lollapalooza 1.0 F.Power 5p Mec.
#   [model] ONIX HATCH 1.0 12V Flex 5p Mec.
#     [year] 2026 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2026 Flex, [valor] R$ 82.783,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2025 Flex, [valor] R$ 70.452,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2024 Flex, [valor] R$ 67.625,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2023 Flex, [valor] R$ 65.845,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2022 Flex, [valor] R$ 62.497,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2021 Flex, [valor] R$ 60.432,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH 1.0 12V Flex 5p Mec., [ano] 2020 Flex, [valor] R$ 53.948,00
#   [model] ONIX HATCH 1.0 12V TB 5p Mec.
#     [year] 2026 Flex
# [modelo] ONIX HATCH 1.0 12V TB 5p Mec., [ano] 2026 Flex, [valor] R$ 95.546,00
#   [model] ONIX HATCH 1.0 12V TB Flex 5p Aut.
#     [year] 2026 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2026 Flex, [valor] R$ 98.895,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 85.233,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 77.928,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2023 Flex, [valor] R$ 72.172,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2022 Flex, [valor] R$ 69.142,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2021 Flex, [valor] R$ 67.003,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH 1.0 12V TB Flex 5p Aut., [ano] 2020 Flex, [valor] R$ 61.450,00
#   [model] ONIX HATCH 100 Anos 1.0 12V 5p Mec.
#     [year] 2026 Flex
# [modelo] ONIX HATCH 100 Anos 1.0 12V 5p Mec., [ano] 2026 Flex, [valor] R$ 90.154,00
#   [model] ONIX HATCH ACTIV 1.4 8V Flex 5P Aut.
#     [year] 2019 Flex
# [modelo] ONIX HATCH ACTIV 1.4 8V Flex 5P Aut., [ano] 2019 Flex, [valor] R$ 69.240,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH ACTIV 1.4 8V Flex 5P Aut., [ano] 2018 Flex, [valor] R$ 66.702,00
#   [model] ONIX HATCH ACTIV 1.4 8V Flex 5p Mec.
#     [year] 2019 Flex
# [modelo] ONIX HATCH ACTIV 1.4 8V Flex 5p Mec., [ano] 2019 Flex, [valor] R$ 66.793,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH ACTIV 1.4 8V Flex 5p Mec., [ano] 2018 Flex, [valor] R$ 63.302,00
#   [model] ONIX HATCH ADVANTAGE 1.4 8V Flex 5p Aut.
#     [year] 2019 Flex
# [modelo] ONIX HATCH ADVANTAGE 1.4 8V Flex 5p Aut., [ano] 2019 Flex, [valor] R$ 66.799,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH ADVANTAGE 1.4 8V Flex 5p Aut., [ano] 2018 Flex, [valor] R$ 62.142,00
#   [model] ONIX HATCH EFFECT 1.4 8V F.Power 5p Mec.
#     [year] 2019 Flex
# [modelo] ONIX HATCH EFFECT 1.4 8V F.Power 5p Mec., [ano] 2019 Flex, [valor] R$ 63.283,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH EFFECT 1.4 8V F.Power 5p Mec., [ano] 2018 Flex, [valor] R$ 61.597,00
#   [model] ONIX HATCH Joy 1.0 8V Flex 5p Mec.
#     [year] 2020 Flex
# [modelo] ONIX HATCH Joy 1.0 8V Flex 5p Mec., [ano] 2020 Flex, [valor] R$ 52.985,00
#     [year] 2019 Flex
# [modelo] ONIX HATCH Joy 1.0 8V Flex 5p Mec., [ano] 2019 Flex, [valor] R$ 49.737,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH Joy 1.0 8V Flex 5p Mec., [ano] 2018 Flex, [valor] R$ 46.233,00
#   [model] ONIX HATCH LS 1.0 8V FlexPower 5p Mec.
#   [model] ONIX HATCH LT 1.0 12V Flex 5p Mec.
#     [year] 2026 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2026 Flex, [valor] R$ 84.322,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2025 Flex, [valor] R$ 72.801,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2024 Flex, [valor] R$ 69.576,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2023 Flex, [valor] R$ 65.711,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2022 Flex, [valor] R$ 61.536,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2021 Flex, [valor] R$ 59.692,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH LT 1.0 12V Flex 5p Mec., [ano] 2020 Flex, [valor] R$ 56.433,00
#   [model] ONIX HATCH LT 1.0 12V TB Flex 5p Aut.
#     [year] 2026 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2026 Flex, [valor] R$ 99.950,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 95.833,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 82.177,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2023 Flex, [valor] R$ 76.138,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2022 Flex, [valor] R$ 72.759,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2021 Flex, [valor] R$ 69.097,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Aut., [ano] 2020 Flex, [valor] R$ 64.952,00
#   [model] ONIX HATCH LT 1.0 12V TB Flex 5p Mec.
#     [year] 2026 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2026 Flex, [valor] R$ 98.985,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2025 Flex, [valor] R$ 85.852,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2024 Flex, [valor] R$ 78.772,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2023 Flex, [valor] R$ 72.962,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2022 Flex, [valor] R$ 70.329,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2021 Flex, [valor] R$ 67.262,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH LT 1.0 12V TB Flex 5p Mec., [ano] 2020 Flex, [valor] R$ 61.931,00
#   [model] ONIX HATCH LT 1.0 8V FlexPower 5p Mec.
#     [year] 2019 Flex
# [modelo] ONIX HATCH LT 1.0 8V FlexPower 5p Mec., [ano] 2019 Flex, [valor] R$ 54.201,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH LT 1.0 8V FlexPower 5p Mec., [ano] 2018 Flex, [valor] R$ 52.059,00
#   [model] ONIX HATCH LT 1.4 8V FlexPower 5p Aut.
#     [year] 2019 Flex
# [modelo] ONIX HATCH LT 1.4 8V FlexPower 5p Aut., [ano] 2019 Flex, [valor] R$ 64.695,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH LT 1.4 8V FlexPower 5p Aut., [ano] 2018 Flex, [valor] R$ 61.175,00
#   [model] ONIX HATCH LT 1.4 8V FlexPower 5p Mec.
#     [year] 2019 Flex
# [modelo] ONIX HATCH LT 1.4 8V FlexPower 5p Mec., [ano] 2019 Flex, [valor] R$ 59.258,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH LT 1.4 8V FlexPower 5p Mec., [ano] 2018 Flex, [valor] R$ 57.812,00
#   [model] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut.
#     [year] 2026 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2026 Flex, [valor] R$ 105.838,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 99.776,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 87.028,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2023 Flex, [valor] R$ 80.981,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2022 Flex, [valor] R$ 73.688,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2021 Flex, [valor] R$ 69.877,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Aut., [ano] 2020 Flex, [valor] R$ 67.918,00
#   [model] ONIX HATCH LTZ 1.0 12V TB Flex 5p Mec.
#     [year] 2023 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Mec., [ano] 2023 Flex, [valor] R$ 74.876,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Mec., [ano] 2022 Flex, [valor] R$ 69.905,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Mec., [ano] 2021 Flex, [valor] R$ 65.453,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH LTZ 1.0 12V TB Flex 5p Mec., [ano] 2020 Flex, [valor] R$ 59.054,00
#   [model] ONIX HATCH LTZ 1.4 8V FlexPower 5p Aut.
#     [year] 2019 Flex
# [modelo] ONIX HATCH LTZ 1.4 8V FlexPower 5p Aut., [ano] 2019 Flex, [valor] R$ 66.852,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH LTZ 1.4 8V FlexPower 5p Aut., [ano] 2018 Flex, [valor] R$ 65.221,00
#   [model] ONIX HATCH LTZ 1.4 8V FlexPower 5p Mec.
#     [year] 2019 Flex
# [modelo] ONIX HATCH LTZ 1.4 8V FlexPower 5p Mec., [ano] 2019 Flex, [valor] R$ 60.965,00
#     [year] 2018 Flex
# [modelo] ONIX HATCH LTZ 1.4 8V FlexPower 5p Mec., [ano] 2018 Flex, [valor] R$ 59.478,00
#   [model] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut.
#     [year] 2026 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2026 Flex, [valor] R$ 119.346,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 100.647,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 92.966,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2023 Flex, [valor] R$ 83.243,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2022 Flex, [valor] R$ 76.361,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2021 Flex, [valor] R$ 72.809,00
#     [year] 2020 Flex
# [modelo] ONIX HATCH PREM. 1.0 12V TB Flex 5p Aut., [ano] 2020 Flex, [valor] R$ 70.435,00
#   [model] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut.
#     [year] 2026 Flex
# [modelo] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut., [ano] 2026 Flex, [valor] R$ 109.878,00
#     [year] 2025 Flex
# [modelo] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut., [ano] 2025 Flex, [valor] R$ 100.889,00
#     [year] 2024 Flex
# [modelo] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut., [ano] 2024 Flex, [valor] R$ 90.590,00
#     [year] 2023 Flex
# [modelo] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut., [ano] 2023 Flex, [valor] R$ 82.391,00
#     [year] 2022 Flex
# [modelo] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut., [ano] 2022 Flex, [valor] R$ 76.411,00
#     [year] 2021 Flex
# [modelo] ONIX HATCH RS 1.0 TB 12V Flex 5p Aut., [ano] 2021 Flex, [valor] R$ 73.518,00
#   [model] ONIX HATCH SELEÇÃO 1.0 8V Flex 5p Mec.
#   [model] ONIX SD. P. PR. MIDNIGHT 1.0 TB Flex Aut
#     [year] 2022 Flex
# [modelo] ONIX SD. P. PR. MIDNIGHT 1.0 TB Flex Aut, [ano] 2022 Flex, [valor] R$ 77.738,00
#     [year] 2021 Flex
# [modelo] ONIX SD. P. PR. MIDNIGHT 1.0 TB Flex Aut, [ano] 2021 Flex, [valor] R$ 71.676,00
#   [model] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut
#     [year] 2026 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2026 Flex, [valor] R$ 119.412,00
#     [year] 2025 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2025 Flex, [valor] R$ 102.049,00
#     [year] 2024 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2024 Flex, [valor] R$ 95.615,00
#     [year] 2023 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2023 Flex, [valor] R$ 83.264,00
#     [year] 2022 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2022 Flex, [valor] R$ 76.450,00
#     [year] 2021 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2021 Flex, [valor] R$ 73.303,00
#     [year] 2020 Flex
# [modelo] ONIX SED. Plus PREM. 1.0 12V TB Flex Aut, [ano] 2020 Flex, [valor] R$ 70.442,00
#   [model] ONIX SEDAN Plus 1.0 12V Mec.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V Mec., [ano] 2026 Flex, [valor] R$ 91.621,00
#   [model] ONIX SEDAN Plus 1.0 12V TB Flex Aut.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2026 Flex, [valor] R$ 107.897,00
#     [year] 2025 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2025 Flex, [valor] R$ 93.727,00
#     [year] 2024 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2024 Flex, [valor] R$ 82.010,00
#     [year] 2023 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2023 Flex, [valor] R$ 77.196,00
#     [year] 2022 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2022 Flex, [valor] R$ 74.676,00
#     [year] 2021 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2021 Flex, [valor] R$ 68.504,00
#     [year] 2020 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Aut., [ano] 2020 Flex, [valor] R$ 62.276,00
#   [model] ONIX SEDAN Plus 1.0 12V TB Flex Mec.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus 1.0 12V TB Flex Mec., [ano] 2026 Flex, [valor] R$ 97.554,00
#   [model] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2026 Flex, [valor] R$ 94.565,00
#     [year] 2025 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2025 Flex, [valor] R$ 76.492,00
#     [year] 2024 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2024 Flex, [valor] R$ 73.932,00
#     [year] 2023 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2023 Flex, [valor] R$ 66.678,00
#     [year] 2022 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2022 Flex, [valor] R$ 61.559,00
#     [year] 2021 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2021 Flex, [valor] R$ 60.057,00
#     [year] 2020 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V Flex 4p Mec., [ano] 2020 Flex, [valor] R$ 57.806,00
#   [model] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2026 Flex, [valor] R$ 107.983,00
#     [year] 2025 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2025 Flex, [valor] R$ 97.450,00
#     [year] 2024 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2024 Flex, [valor] R$ 84.048,00
#     [year] 2023 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2023 Flex, [valor] R$ 77.585,00
#     [year] 2022 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2022 Flex, [valor] R$ 75.482,00
#     [year] 2021 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2021 Flex, [valor] R$ 68.514,00
#     [year] 2020 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Aut., [ano] 2020 Flex, [valor] R$ 66.023,00
#   [model] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2026 Flex, [valor] R$ 103.616,00
#     [year] 2025 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2025 Flex, [valor] R$ 88.015,00
#     [year] 2024 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2024 Flex, [valor] R$ 78.854,00
#     [year] 2023 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2023 Flex, [valor] R$ 73.114,00
#     [year] 2022 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2022 Flex, [valor] R$ 70.521,00
#     [year] 2021 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2021 Flex, [valor] R$ 67.320,00
#     [year] 2020 Flex
# [modelo] ONIX SEDAN Plus LT 1.0 12V TB Flex Mec., [ano] 2020 Flex, [valor] R$ 61.985,00
#   [model] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut.
#     [year] 2026 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2026 Flex, [valor] R$ 111.983,00
#     [year] 2025 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2025 Flex, [valor] R$ 97.562,00
#     [year] 2024 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2024 Flex, [valor] R$ 84.075,00
#     [year] 2023 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2023 Flex, [valor] R$ 77.685,00
#     [year] 2022 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2022 Flex, [valor] R$ 75.541,00
#     [year] 2021 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2021 Flex, [valor] R$ 68.652,00
#     [year] 2020 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Aut., [ano] 2020 Flex, [valor] R$ 66.097,00
#   [model] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Mec.
#     [year] 2023 Flex
# [modelo] ONIX SEDAN Plus LTZ 1.0 12V TB Flex Mec., [ano] 2023 Flex, [valor] R$ 74.464,00
#     [year] 2022 Flex
# ...
# [modelo] ETIOS X 1.3 Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 67.296,00
#     [year] 2020 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Aut., [ano] 2020 Flex, [valor] R$ 60.315,00
#     [year] 2019 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 58.814,00
#     [year] 2018 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Aut., [ano] 2018 Flex, [valor] R$ 56.846,00
#   [model] ETIOS X 1.3 Flex 16V 5p Mec.
#     [year] 2021 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Mec., [ano] 2021 Flex, [valor] R$ 65.586,00
#     [year] 2020 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Mec., [ano] 2020 Flex, [valor] R$ 59.259,00
#     [year] 2019 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Mec., [ano] 2019 Flex, [valor] R$ 57.813,00
#     [year] 2018 Flex
# [modelo] ETIOS X 1.3 Flex 16V 5p Mec., [ano] 2018 Flex, [valor] R$ 54.274,00
#   [model] ETIOS X Plus 1.5 Flex 16V 5p Aut.
#     [year] 2021 Flex
# [modelo] ETIOS X Plus 1.5 Flex 16V 5p Aut., [ano] 2021 Flex, [valor] R$ 73.625,00
#     [year] 2020 Flex
# [modelo] ETIOS X Plus 1.5 Flex 16V 5p Aut., [ano] 2020 Flex, [valor] R$ 69.181,00
#     [year] 2019 Flex
# [modelo] ETIOS X Plus 1.5 Flex 16V 5p Aut., [ano] 2019 Flex, [valor] R$ 66.233,00
#   [model] ETIOS X Plus 1.5 Flex 16V 5p Mec.
#     [year] 2021 Flex
# [modelo] ETIOS X Plus 1.5 Flex 16V 5p Mec., [ano] 2021 Flex, [valor] R$ 68.994,00
#     [year] 2020 Flex
# [modelo] ETIOS X Plus 1.5 Flex 16V 5p Mec., [ano] 2020 Flex, [valor] R$ 62.973,00
#     [year] 2019 Flex
# [modelo] ETIOS X Plus 1.5 Flex 16V 5p Mec., [ano] 2019 Flex, [valor] R$ 60.030,00
#   [model] ETIOS X Plus Sedan 1.5 Flex 16V 4p Aut.
#     [year] 2021 Flex
# [modelo] ETIOS X Plus Sedan 1.5 Flex 16V 4p Aut., [ano] 2021 Flex, [valor] R$ 72.905,00
#     [year] 2020 Flex
# [modelo] ETIOS X Plus Sedan 1.5 Flex 16V 4p Aut., [ano] 2020 Flex, [valor] R$ 66.306,00
#     [year] 2019 Flex
# [modelo] ETIOS X Plus Sedan 1.5 Flex 16V 4p Aut., [ano] 2019 Flex, [valor] R$ 63.441,00
#   [model] ETIOS X Plus Sedan 1.5 Flex 16V 4p Mec.
#     [year] 2021 Flex
# [modelo] ETIOS X Plus Sedan 1.5 Flex 16V 4p Mec., [ano] 2021 Flex, [valor] R$ 66.558,00
#     [year] 2020 Flex
# [modelo] ETIOS X Plus Sedan 1.5 Flex 16V 4p Mec., [ano] 2020 Flex, [valor] R$ 61.876,00
#     [year] 2019 Flex
# [modelo] ETIOS X Plus Sedan 1.5 Flex 16V 4p Mec., [ano] 2019 Flex, [valor] R$ 60.111,00
#   [model] ETIOS X Sedan 1.5 Flex 16V 4p Aut.
#     [year] 2021 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Aut., [ano] 2021 Flex, [valor] R$ 66.367,00
#     [year] 2020 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Aut., [ano] 2020 Flex, [valor] R$ 61.863,00
#     [year] 2019 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Aut., [ano] 2019 Flex, [valor] R$ 58.605,00
#     [year] 2018 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Aut., [ano] 2018 Flex, [valor] R$ 57.125,00
#   [model] ETIOS X Sedan 1.5 Flex 16V 4p Mec.
#     [year] 2021 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Mec., [ano] 2021 Flex, [valor] R$ 67.718,00
#     [year] 2020 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Mec., [ano] 2020 Flex, [valor] R$ 60.366,00
#     [year] 2019 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Mec., [ano] 2019 Flex, [valor] R$ 58.894,00
#     [year] 2018 Flex
# [modelo] ETIOS X Sedan 1.5 Flex 16V 4p Mec., [ano] 2018 Flex, [valor] R$ 57.457,00
#   [model] ETIOS XLS 1.5 Flex 16V 5p Mec.
#   [model] ETIOS XLS 1.5 Flex 5p Aut.
#     [year] 2019 Flex
# [modelo] ETIOS XLS 1.5 Flex 5p Aut., [ano] 2019 Flex, [valor] R$ 65.864,00
#     [year] 2018 Flex
# [modelo] ETIOS XLS 1.5 Flex 5p Aut., [ano] 2018 Flex, [valor] R$ 62.293,00
#   [model] ETIOS XLS Sedan 1.5 Flex 16V 4p Aut.
#     [year] 2019 Flex
# [modelo] ETIOS XLS Sedan 1.5 Flex 16V 4p Aut., [ano] 2019 Flex, [valor] R$ 67.181,00
#     [year] 2018 Flex
# [modelo] ETIOS XLS Sedan 1.5 Flex 16V 4p Aut., [ano] 2018 Flex, [valor] R$ 62.330,00
#   [model] ETIOS XLS Sedan 1.5 Flex 16V 4p Mec.
#   [model] ETIOS XS  1.3 Flex 16V 5p Mec.
#   [model] ETIOS XS 1.5 Flex 16V 5p Aut.
#     [year] 2018 Flex
# [modelo] ETIOS XS 1.5 Flex 16V 5p Aut., [ano] 2018 Flex, [valor] R$ 62.111,00
#   [model] ETIOS XS 1.5 Flex 16V 5p Mec.
#     [year] 2018 Flex
# [modelo] ETIOS XS 1.5 Flex 16V 5p Mec., [ano] 2018 Flex, [valor] R$ 56.651,00
#   [model] ETIOS XS Sedan 1.5 Flex 16V 4p Aut.
#     [year] 2018 Flex
# [modelo] ETIOS XS Sedan 1.5 Flex 16V 4p Aut., [ano] 2018 Flex, [valor] R$ 60.282,00
#   [model] ETIOS XS Sedan1.5 Flex 16V 4p Mec.
#     [year] 2018 Flex
# [modelo] ETIOS XS Sedan1.5 Flex 16V 4p Mec., [ano] 2018 Flex, [valor] R$ 59.108,00
# [brand] Honda
#   [model_lbl] civic
#   [model] Civic Coupe EX/ EXS 1.6 16V 2p
#   [model] Civic Coupe Si 1.5 TB 16V 208cv Mec. 2p
#     [year] 2020 Gasolina
# [modelo] Civic Coupe Si 1.5 TB 16V 208cv Mec. 2p, [ano] 2020 Gasolina, [valor] R$ 174.116,00
#     [year] 2019 Gasolina
# [modelo] Civic Coupe Si 1.5 TB 16V 208cv Mec. 2p, [ano] 2019 Gasolina, [valor] R$ 169.869,00
#     [year] 2018 Gasolina
# [modelo] Civic Coupe Si 1.5 TB 16V 208cv Mec. 2p, [ano] 2018 Gasolina, [valor] R$ 163.252,00
#   [model] Civic Coupe Si 2.4 16V 206cv Mec. 2p
#   [model] Civic CRX/ Targa VTi
#   [model] Civic Hatch DX
#   [model] Civic Hatch LSi
#   [model] Civic Hatch LX Aut.
#   [model] Civic Hatch Si
#   [model] Civic Hatch VTi
#   [model] Civic Sed LX 1.8 Aut 4p
#   [model] Civic Sed. LXL/ LXL SE 1.8 Flex 16V Aut.
#   [model] Civic Sed. LXL/LXL SE 1.8 Flex 16V Mec.
#   [model] Civic Sed.Touring 2.0 16V Aut. (Híbrido)
#     [year] 2025 Híbrido
# [modelo] Civic Sed.Touring 2.0 16V Aut. (Híbrido), [ano] 2025 Híbrido, [valor] R$ 223.108,00
#     [year] 2024 Híbrido
# [modelo] Civic Sed.Touring 2.0 16V Aut. (Híbrido), [ano] 2024 Híbrido, [valor] R$ 204.797,00
#     [year] 2023 Híbrido
# [modelo] Civic Sed.Touring 2.0 16V Aut. (Híbrido), [ano] 2023 Híbrido, [valor] R$ 188.123,00
#   [model] Civic Sedan EX 1.6 16V Aut. 4p (nacion.)
#   [model] Civic Sedan EX 1.6 16V Mec. 4p (nacion.)
#   [model] Civic Sedan EX 1.7 16V 130cv Aut. 4p
#   [model] Civic Sedan EX 1.7 16v 130cv Mec. 4p
#   [model] Civic Sedan EX 2.0 Flex 16V Aut.4p
#     [year] 2021 Flex
# [modelo] Civic Sedan EX 2.0 Flex 16V Aut.4p, [ano] 2021 Flex, [valor] R$ 124.162,00
#     [year] 2020 Flex
# [modelo] Civic Sedan EX 2.0 Flex 16V Aut.4p, [ano] 2020 Flex, [valor] R$ 118.587,00
#     [year] 2019 Flex
# [modelo] Civic Sedan EX 2.0 Flex 16V Aut.4p, [ano] 2019 Flex, [valor] R$ 110.591,00
#     [year] 2018 Flex
# [modelo] Civic Sedan EX 2.0 Flex 16V Aut.4p, [ano] 2018 Flex, [valor] R$ 106.206,00
#   [model] Civic Sedan EX/ EXS 1.6 Mec. 4p
#   [model] Civic Sedan EX/ EXS Aut. 4p/ Del-Sol 2p
#   [model] Civic Sedan EXL 2.0 Flex 16V Aut.4p
#     [year] 2021 Flex
# [modelo] Civic Sedan EXL 2.0 Flex 16V Aut.4p, [ano] 2021 Flex, [valor] R$ 129.278,00
#     [year] 2020 Flex
# [modelo] Civic Sedan EXL 2.0 Flex 16V Aut.4p, [ano] 2020 Flex, [valor] R$ 120.023,00
#     [year] 2019 Flex
# [modelo] Civic Sedan EXL 2.0 Flex 16V Aut.4p, [ano] 2019 Flex, [valor] R$ 112.586,00
#     [year] 2018 Flex
# [modelo] Civic Sedan EXL 2.0 Flex 16V Aut.4p, [ano] 2018 Flex, [valor] R$ 108.947,00
#   [model] Civic Sedan EXR 2.0 Flexone 16V Aut. 4p
#   [model] Civic Sedan EXS 1.8/1.8 Flex 16V Aut. 4p
#   [model] Civic Sedan LX 1.5/1.6
#   [model] Civic Sedan LX 1.6 16V Aut. 4p
#   [model] Civic Sedan LX 1.6 16V Mec. 4p
#   [model] Civic Sedan LX 1.7 16V 115cv Mec. 4p
#   [model] Civic Sedan LX 2.0 Flex 16V Aut. 4p
#     [year] 2021 Flex
# [modelo] Civic Sedan LX 2.0 Flex 16V Aut. 4p, [ano] 2021 Flex, [valor] R$ 119.123,00
#     [year] 2020 Flex
# [modelo] Civic Sedan LX 2.0 Flex 16V Aut. 4p, [ano] 2020 Flex, [valor] R$ 111.448,00
#   [model] Civic Sedan LX/LXL 1.7 16V 115cv Aut. 4p
#   [model] Civic Sedan LXB 1.6 16V 4p
#   [model] Civic Sedan LXB 1.7 16V 115cv
#   [model] Civic Sedan LXL 1.7 16V 130cv Aut 4p
#   [model] Civic Sedan LXL 1.7 16V 130cv Mec 4p
#   [model] Civic Sedan LXR 2.0 Flexone 16V Aut. 4p
#   [model] Civic Sedan LXS 1.8/1.8 Flex 16V Aut. 4p
#   [model] Civic Sedan LXS 1.8/1.8 Flex 16V Mec. 4p
#   [model] Civic Sedan Si 2.0 16V  192cv 4p
#   [model] Civic Sedan SPORT 2.0 Flex 16V Aut.4p
#     [year] 2021 Flex
# [modelo] Civic Sedan SPORT 2.0 Flex 16V Aut.4p, [ano] 2021 Flex, [valor] R$ 120.286,00
#     [year] 2020 Flex
# [modelo] Civic Sedan SPORT 2.0 Flex 16V Aut.4p, [ano] 2020 Flex, [valor] R$ 112.047,00
#     [year] 2019 Flex
# [modelo] Civic Sedan SPORT 2.0 Flex 16V Aut.4p, [ano] 2019 Flex, [valor] R$ 106.536,00
#     [year] 2018 Flex
# [modelo] Civic Sedan SPORT 2.0 Flex 16V Aut.4p, [ano] 2018 Flex, [valor] R$ 103.319,00
#   [model] Civic Sedan SPORT 2.0 Flex 16V Mec.4p
#     [year] 2019 Flex
# [modelo] Civic Sedan SPORT 2.0 Flex 16V Mec.4p, [ano] 2019 Flex, [valor] R$ 105.775,00
#     [year] 2018 Flex
# [modelo] Civic Sedan SPORT 2.0 Flex 16V Mec.4p, [ano] 2018 Flex, [valor] R$ 100.852,00
#   [model] Civic Sedan TOURING 1.5 Turbo 16V Aut.4p
#     [year] 2021 Gasolina
# [modelo] Civic Sedan TOURING 1.5 Turbo 16V Aut.4p, [ano] 2021 Gasolina, [valor] R$ 149.793,00
#     [year] 2020 Gasolina
# [modelo] Civic Sedan TOURING 1.5 Turbo 16V Aut.4p, [ano] 2020 Gasolina, [valor] R$ 137.411,00
#     [year] 2019 Gasolina
# [modelo] Civic Sedan TOURING 1.5 Turbo 16V Aut.4p, [ano] 2019 Gasolina, [valor] R$ 129.467,00
#     [year] 2018 Gasolina
# [modelo] Civic Sedan TOURING 1.5 Turbo 16V Aut.4p, [ano] 2018 Gasolina, [valor] R$ 124.587,00
#   [model] Civic Type-R 2.0 Turbo 16V
#     [year] 2025 Gasolina
# [modelo] Civic Type-R 2.0 Turbo 16V, [ano] 2025 Gasolina, [valor] R$ 389.562,00
#     [year] 2024 Gasolina
# [modelo] Civic Type-R 2.0 Turbo 16V, [ano] 2024 Gasolina, [valor] R$ 375.810,00
#     [year] 2023 Gasolina
# [modelo] Civic Type-R 2.0 Turbo 16V, [ano] 2023 Gasolina, [valor] R$ 358.367,00
#   [model_lbl] city
#   [model] CITY Hatchback EX 1.5 Flex 16V Aut.
#     [year] 2026 Flex
# [modelo] CITY Hatchback EX 1.5 Flex 16V Aut., [ano] 2026 Flex, [valor] R$ 129.728,00
#     [year] 2025 Flex
# [modelo] CITY Hatchback EX 1.5 Flex 16V Aut., [ano] 2025 Flex, [valor] R$ 118.845,00
#     [year] 2024 Flex
# [modelo] CITY Hatchback EX 1.5 Flex 16V Aut., [ano] 2024 Flex, [valor] R$ 108.949,00
#   [model] CITY Hatchback EXL 1.5 Flex 16V Aut.
#     [year] 2026 Flex
# [modelo] CITY Hatchback EXL 1.5 Flex 16V Aut., [ano] 2026 Flex, [valor] R$ 137.998,00
#     [year] 2025 Flex
# [modelo] CITY Hatchback EXL 1.5 Flex 16V Aut., [ano] 2025 Flex, [valor] R$ 131.773,00
#     [year] 2024 Flex
# [modelo] CITY Hatchback EXL 1.5 Flex 16V Aut., [ano] 2024 Flex, [valor] R$ 126.438,00
#     [year] 2023 Flex
# [modelo] CITY Hatchback EXL 1.5 Flex 16V Aut., [ano] 2023 Flex, [valor] R$ 113.378,00
#     [year] 2022 Flex
# [modelo] CITY Hatchback EXL 1.5 Flex 16V Aut., [ano] 2022 Flex, [valor] R$ 99.349,00
#   [model] CITY Hatchback LX 1.5 Flex 16V Aut.
#     [year] 2026 Flex
# [modelo] CITY Hatchback LX 1.5 Flex 16V Aut., [ano] 2026 Flex, [valor] R$ 112.015,00
#     [year] 2025 Flex
# [modelo] CITY Hatchback LX 1.5 Flex 16V Aut., [ano] 2025 Flex, [valor] R$ 109.203,00
#     [year] 2024 Flex
# [modelo] CITY Hatchback LX 1.5 Flex 16V Aut., [ano] 2024 Flex, [valor] R$ 103.780,00
#   [model] CITY Hatchback Touring 1.5 Flex 16V Aut
#     [year] 2026 Flex
# [modelo] CITY Hatchback Touring 1.5 Flex 16V Aut, [ano] 2026 Flex, [valor] R$ 140.859,00
#     [year] 2025 Flex
# [modelo] CITY Hatchback Touring 1.5 Flex 16V Aut, [ano] 2025 Flex, [valor] R$ 132.435,00
#     [year] 2024 Flex
# [modelo] CITY Hatchback Touring 1.5 Flex 16V Aut, [ano] 2024 Flex, [valor] R$ 126.967,00
#     [year] 2023 Flex
# [modelo] CITY Hatchback Touring 1.5 Flex 16V Aut, [ano] 2023 Flex, [valor] R$ 114.172,00
#     [year] 2022 Flex
# [modelo] CITY Hatchback Touring 1.5 Flex 16V Aut, [ano] 2022 Flex, [valor] R$ 103.040,00
#   [model] CITY Hatchback Touring Sport 1.5 16V Aut
#     [year] 2026 Flex
# [modelo] CITY Hatchback Touring Sport 1.5 16V Aut, [ano] 2026 Flex, [valor] R$ 141.277,00
#   [model] CITY Sedan DX 1.5 Flex 16V Aut.
#   [model] CITY Sedan DX 1.5 Flex 16V Mec.
#     [year] 2021 Flex
# [modelo] CITY Sedan DX 1.5 Flex 16V Mec., [ano] 2021 Flex, [valor] R$ 75.529,00
#     [year] 2020 Flex
# [modelo] CITY Sedan DX 1.5 Flex 16V Mec., [ano] 2020 Flex, [valor] R$ 73.686,00
#     [year] 2019 Flex
# [modelo] CITY Sedan DX 1.5 Flex 16V Mec., [ano] 2019 Flex, [valor] R$ 71.888,00
#     [year] 2018 Flex
# [modelo] CITY Sedan DX 1.5 Flex 16V Mec., [ano] 2018 Flex, [valor] R$ 70.134,00
#   [model] CITY Sedan EX 1.5 Flex 16V 4p Aut.
#     [year] 2026 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2026 Flex, [valor] R$ 124.515,00
#     [year] 2025 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2025 Flex, [valor] R$ 120.495,00
#     [year] 2024 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2024 Flex, [valor] R$ 110.662,00
#     [year] 2023 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2023 Flex, [valor] R$ 102.284,00
#     [year] 2022 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2022 Flex, [valor] R$ 95.562,00
#     [year] 2021 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2021 Flex, [valor] R$ 88.555,00
#     [year] 2020 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2020 Flex, [valor] R$ 86.395,00
#     [year] 2019 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2019 Flex, [valor] R$ 80.760,00
#     [year] 2018 Flex
# [modelo] CITY Sedan EX 1.5 Flex 16V 4p Aut., [ano] 2018 Flex, [valor] R$ 78.790,00
#   [model] CITY Sedan EX 1.5 Flex 16V 4p Mec.
#   [model] CITY Sedan EXL 1.5 Flex  16V 4p Aut.
#     [year] 2026 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2026 Flex, [valor] R$ 137.718,00
#     [year] 2025 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2025 Flex, [valor] R$ 126.112,00
#     [year] 2024 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2024 Flex, [valor] R$ 117.392,00
#     [year] 2023 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2023 Flex, [valor] R$ 106.613,00
#     [year] 2022 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2022 Flex, [valor] R$ 99.137,00
#     [year] 2021 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2021 Flex, [valor] R$ 91.545,00
#     [year] 2020 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2020 Flex, [valor] R$ 89.312,00
#     [year] 2019 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2019 Flex, [valor] R$ 85.100,00
#     [year] 2018 Flex
# [modelo] CITY Sedan EXL 1.5 Flex  16V 4p Aut., [ano] 2018 Flex, [valor] R$ 83.024,00
#   [model] CITY Sedan EXL 1.5 Flex 16V 4p Mec.
#   [model] CITY Sedan LX 1.5 Flex 16V 4p Aut.
#     [year] 2026 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2026 Flex, [valor] R$ 112.252,00
#     [year] 2025 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2025 Flex, [valor] R$ 109.333,00
#     [year] 2024 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2024 Flex, [valor] R$ 104.160,00
#     [year] 2021 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2021 Flex, [valor] R$ 87.975,00
#     [year] 2020 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2020 Flex, [valor] R$ 84.124,00
#     [year] 2019 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2019 Flex, [valor] R$ 79.775,00
#     [year] 2018 Flex
# [modelo] CITY Sedan LX 1.5 Flex 16V 4p Aut., [ano] 2018 Flex, [valor] R$ 76.600,00
#   [model] CITY Sedan LX 1.5 Flex 16V 4p Mec.
#   [model] CITY Sedan Personal 1.5 Flex 16V Aut.
#     [year] 2021 Flex
# [modelo] CITY Sedan Personal 1.5 Flex 16V Aut., [ano] 2021 Flex, [valor] R$ 88.573,00
#     [year] 2020 Flex
# [modelo] CITY Sedan Personal 1.5 Flex 16V Aut., [ano] 2020 Flex, [valor] R$ 84.754,00
#     [year] 2019 Flex
# [modelo] CITY Sedan Personal 1.5 Flex 16V Aut., [ano] 2019 Flex, [valor] R$ 79.890,00
#     [year] 2018 Flex
# [modelo] CITY Sedan Personal 1.5 Flex 16V Aut., [ano] 2018 Flex, [valor] R$ 77.941,00
#   [model] CITY Sedan SPORT 1.5 FLEX 16V 4p Mec.
#   [model] CITY Sedan Touring 1.5 Flex 16V 4p Aut.
#     [year] 2026 Flex
# [modelo] CITY Sedan Touring 1.5 Flex 16V 4p Aut., [ano] 2026 Flex, [valor] R$ 142.358,00
#     [year] 2025 Flex
# [modelo] CITY Sedan Touring 1.5 Flex 16V 4p Aut., [ano] 2025 Flex, [valor] R$ 132.853,00
#     [year] 2024 Flex
# [modelo] CITY Sedan Touring 1.5 Flex 16V 4p Aut., [ano] 2024 Flex, [valor] R$ 127.021,00
#     [year] 2023 Flex
# [modelo] CITY Sedan Touring 1.5 Flex 16V 4p Aut., [ano] 2023 Flex, [valor] R$ 115.201,00
#     [year] 2022 Flex
# [modelo] CITY Sedan Touring 1.5 Flex 16V 4p Aut., [ano] 2022 Flex, [valor] R$ 103.284,00

# %%
def flatten_modelos_keep_all(data):
    rows = []

    for modelo_nome, modelo_data in data.items():

        # Case 1 — model is just a code (no years yet)
        if not isinstance(modelo_data, dict):
            rows.append({
                "Modelo": modelo_nome,
                "CodigoModelo": modelo_data,
                "AnoLabel": None,
                "AnoModelo": None,
                "Combustivel": None,
                "Valor": None,
                "CodigoFipe": None,
                "MesReferencia": None,
                "DataConsulta": None,
            })
            continue

        codigo_modelo = modelo_data.get("codigo_modelo")
        anos = modelo_data.get("anos")

        # Case 2 — model has no years
        if not anos:
            rows.append({
                "Modelo": modelo_nome,
                "CodigoModelo": codigo_modelo,
                "AnoLabel": None,
                "AnoModelo": None,
                "Combustivel": None,
                "Valor": None,
                "CodigoFipe": None,
                "MesReferencia": None,
                "DataConsulta": None,
            })
            continue

        # Case 3 — model has years
        for ano_label, ano_data in anos.items():

            # If year is just a string like "2024-6"
            if not isinstance(ano_data, dict):
                rows.append({
                    "Modelo": modelo_nome,
                    "CodigoModelo": codigo_modelo,
                    "AnoLabel": ano_label,
                    "AnoModelo": int(ano_label[:4]) if ano_label[:4].isdigit() else None,
                    "Combustivel": None,
                    "Valor": None,
                    "CodigoFipe": None,
                    "MesReferencia": None,
                    "DataConsulta": None,
                })
                continue

            detalhes = ano_data.get("detalhes", {})

            rows.append({
                "Modelo": modelo_nome,
                "CodigoModelo": codigo_modelo,
                "AnoLabel": ano_label,
                "AnoModelo": detalhes.get("AnoModelo"),
                "Combustivel": detalhes.get("Combustivel"),
                "Valor": detalhes.get("Valor"),
                "CodigoFipe": detalhes.get("CodigoFipe"),
                "MesReferencia": detalhes.get("MesReferencia"),
                "DataConsulta": detalhes.get("DataConsulta"),
            })

            df = pd.DataFrame(rows)

            df["Valor_num"] = (
            df["Valor"]
            .str.replace("R$ ", "", regex=False)
            .str.replace(".", "", regex=False)
                .str.replace(",", ".", regex=False)
            )

            df["Valor_num"] = pd.to_numeric(df["Valor_num"], errors="coerce")

    return df

# %%
df_all_marcas = pd.DataFrame()

for marca_ in mdls_consult.keys():

    data = {}

    with open(f"{marca_}_target.json", "r", encoding="utf-8") as f:
        buffer = ""
        for line in f:
            buffer += line.strip()
            try:
                obj = json.loads(buffer)
                data.update(obj)
                buffer = ""
            except json.JSONDecodeError:
                continue

    df = flatten_modelos_keep_all(data)
    df["Marca"] = marca_
    df_all_marcas = pd.concat([df_all_marcas, df], ignore_index=True)
    print(f"[{marca_}] rows: {len(df)}, total: {len(df_all_marcas)}")
# Out:
# [VW - VolksWagen] rows: 432, total: 432
# [GM - Chevrolet] rows: 151, total: 583
# [Hyundai] rows: 269, total: 852
# [Fiat] rows: 231, total: 1083
# [Ford] rows: 153, total: 1236
# [Renault] rows: 188, total: 1424
# [Toyota] rows: 153, total: 1577
# [Honda] rows: 121, total: 1698

# %%
df_all_marcas.to_csv(f"fipe_data_{cod_ref}.csv", index=False, encoding="utf-8-sig")
